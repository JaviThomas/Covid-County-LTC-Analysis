# %% [markdown]
# ### Doing
#  - [ ] Add CMS_IDs to Outbreaks and Facilities
#
# ### To Do
#  - [ ] Group Facilities by CMS_Provider_Num WHERE Available
#
# ### DONE
#  - [x] Separate funtions into separate Python files

# %%
import pandas as pd
import urllib3 as urllib
import urllib.request as urllib2
import json
import glob
import IPython.display
import altair as alt

from Modules.IL_Functions import *

pd.options.display.max_columns = None

# %% [markdown]
# ## 1 - Get "Raw Data" from website and store in file

# %%
[reporting_date, ltc_data] = pull_IL_json_from_web()

# %%
# print('Source File: ' + str(json_file))
[reporting_date, summary, outbreak_df, df_facilities, df_county] = process_IL_dict(ltc_data, ltc_name2cms_id, display_dfs=False)
# Out:
# Date: 2021-01-15
# Cases: 69398
# Deaths: 8986
# Outbreaks: 1922
# Open Outbreaks: 1006
# Closed Outbreaks: 916
# Facilities: 1525

# %%
# outbreak_df.groupby(['County', 'FacilityName']).sum()

# %%
df_facilities.sort_values(by='Open_Outbreaks', ascending=False).head(20)
# Out:
#                                                                       ReportingDate  \
# County    FacilityName2                                   CMS_ProvNum
# Cook      Aperion Care West Ridge                         145832         2021-01-15
#           Lincolnwood Place                               145786         2021-01-15
#           Symphony of South Shore                         145977         2021-01-15
#           Symphony of Morgan Park                         145764         2021-01-15
#           Austin Oasis                                    145834         2021-01-15
#           Balmoral Home                                   145796         2021-01-15
#           Alden North Shore                               145984         2021-01-15
#           SHERIDAN VILLAGE NURSING HOME                   No Match       2021-01-15
# Lake      Rolling Hills Manor                             145443         2021-01-15
# Vermilion Accolade Health Care of Danville                No Match       2021-01-15
# Cook      Citadel of Skokie                               145468         2021-01-15
#           Arbour Health Care Center                       146169         2021-01-15
#           Lakeview Nursing and Rehab                      145654         2021-01-15
# Marion    Bryan Manor                                     No Match       2021-01-15
# Lake      Sunrise of Buffalo Grove                        No Match       2021-01-15
# Marion    Cottages at Salem                               No Match       2021-01-15
# Lake      Storypoint Libertyville                         No Match       2021-01-15
#           Stonebridge of Gurnee                           No Match       2021-01-15
#           Springs of Vernon Hills Alzheimers Special Care No Match       2021-01-15
#           Sheridan at Green Oaks Senior Living            No Match       2021-01-15
#
#                                                                        confirmed_cases  \
# County    FacilityName2                                   CMS_ProvNum
# Cook      Aperion Care West Ridge                         145832                    61
#           Lincolnwood Place                               145786                   137
#           Symphony of South Shore                         145977                   230
#           Symphony of Morgan Park                         145764                   212
#           Austin Oasis                                    145834                   115
#           Balmoral Home                                   145796                    60
#           Alden North Shore                               145984                    14
#           SHERIDAN VILLAGE NURSING HOME                   No Match                  10
# Lake      Rolling Hills Manor                             145443                   122
# Vermilion Accolade Health Care of Danville                No Match                  22
# Cook      Citadel of Skokie                               145468                    53
#           Arbour Health Care Center                       146169                    85
#           Lakeview Nursing and Rehab                      145654                   100
# Marion    Bryan Manor                                     No Match                 155
# Lake      Sunrise of Buffalo Grove                        No Match                  11
# Marion    Cottages at Salem                               No Match                   3
# Lake      Storypoint Libertyville                         No Match                   8
#           Stonebridge of Gurnee                           No Match                  12
#           Springs of Vernon Hills Alzheimers Special Care No Match                  35
#           Sheridan at Green Oaks Senior Living            No Match                  10
#
#                                                                        deaths  \
# County    FacilityName2                                   CMS_ProvNum
# Cook      Aperion Care West Ridge                         145832           14
#           Lincolnwood Place                               145786           33
#           Symphony of South Shore                         145977           35
#           Symphony of Morgan Park                         145764           26
#           Austin Oasis                                    145834           16
#           Balmoral Home                                   145796            4
#           Alden North Shore                               145984            3
#           SHERIDAN VILLAGE NURSING HOME                   No Match          0
# Lake      Rolling Hills Manor                             145443           21
# Vermilion Accolade Health Care of Danville                No Match          8
# Cook      Citadel of Skokie                               145468           14
#           Arbour Health Care Center                       146169            3
#           Lakeview Nursing and Rehab                      145654           22
# Marion    Bryan Manor                                     No Match          8
# Lake      Sunrise of Buffalo Grove                        No Match          0
# Marion    Cottages at Salem                               No Match          0
# Lake      Storypoint Libertyville                         No Match          2
#           Stonebridge of Gurnee                           No Match          0
#           Springs of Vernon Hills Alzheimers Special Care No Match          1
#           Sheridan at Green Oaks Senior Living            No Match          1
#
#                                                                             CFR  \
# County    FacilityName2                                   CMS_ProvNum
# Cook      Aperion Care West Ridge                         145832       0.229508
#           Lincolnwood Place                               145786       0.240876
#           Symphony of South Shore                         145977       0.152174
#           Symphony of Morgan Park                         145764       0.122642
#           Austin Oasis                                    145834       0.139130
#           Balmoral Home                                   145796       0.066667
#           Alden North Shore                               145984       0.214286
#           SHERIDAN VILLAGE NURSING HOME                   No Match     0.000000
# Lake      Rolling Hills Manor                             145443       0.172131
# Vermilion Accolade Health Care of Danville                No Match     0.363636
# Cook      Citadel of Skokie                               145468       0.264151
#           Arbour Health Care Center                       146169       0.035294
#           Lakeview Nursing and Rehab                      145654       0.220000
# Marion    Bryan Manor                                     No Match     0.051613
# Lake      Sunrise of Buffalo Grove                        No Match     0.000000
# Marion    Cottages at Salem                               No Match     0.000000
# Lake      Storypoint Libertyville                         No Match     0.250000
#           Stonebridge of Gurnee                           No Match     0.000000
#           Springs of Vernon Hills Alzheimers Special Care No Match     0.028571
#           Sheridan at Green Oaks Senior Living            No Match     0.100000
#
#                                                                        outbreaks  \
# County    FacilityName2                                   CMS_ProvNum
# Cook      Aperion Care West Ridge                         145832               3
#           Lincolnwood Place                               145786               2
#           Symphony of South Shore                         145977               2
#           Symphony of Morgan Park                         145764               2
#           Austin Oasis                                    145834               2
#           Balmoral Home                                   145796               2
#           Alden North Shore                               145984               3
#           SHERIDAN VILLAGE NURSING HOME                   No Match             2
# Lake      Rolling Hills Manor                             145443               3
# Vermilion Accolade Health Care of Danville                No Match             2
# Cook      Citadel of Skokie                               145468               3
#           Arbour Health Care Center                       146169               3
#           Lakeview Nursing and Rehab                      145654               2
# Marion    Bryan Manor                                     No Match             1
# Lake      Sunrise of Buffalo Grove                        No Match             2
# Marion    Cottages at Salem                               No Match             1
# Lake      Storypoint Libertyville                         No Match             1
#           Stonebridge of Gurnee                           No Match             2
#           Springs of Vernon Hills Alzheimers Special Care No Match             1
#           Sheridan at Green Oaks Senior Living            No Match             1
#
#                                                                        Closed_Outbreaks  \
# County    FacilityName2                                   CMS_ProvNum
# Cook      Aperion Care West Ridge                         145832                      1
#           Lincolnwood Place                               145786                      0
#           Symphony of South Shore                         145977                      0
#           Symphony of Morgan Park                         145764                      0
#           Austin Oasis                                    145834                      0
#           Balmoral Home                                   145796                      0
#           Alden North Shore                               145984                      1
#           SHERIDAN VILLAGE NURSING HOME                   No Match                    0
# Lake      Rolling Hills Manor                             145443                      1
# Vermilion Accolade Health Care of Danville                No Match                    0
# Cook      Citadel of Skokie                               145468                      1
#           Arbour Health Care Center                       146169                      1
#           Lakeview Nursing and Rehab                      145654                      0
# Marion    Bryan Manor                                     No Match                    0
# Lake      Sunrise of Buffalo Grove                        No Match                    1
# Marion    Cottages at Salem                               No Match                    0
# Lake      Storypoint Libertyville                         No Match                    0
#           Stonebridge of Gurnee                           No Match                    1
#           Springs of Vernon Hills Alzheimers Special Care No Match                    0
#           Sheridan at Green Oaks Senior Living            No Match                    0
#
#                                                                        Open_Outbreaks  \
# County    FacilityName2                                   CMS_ProvNum
# Cook      Aperion Care West Ridge                         145832                    2
#           Lincolnwood Place                               145786                    2
#           Symphony of South Shore                         145977                    2
#           Symphony of Morgan Park                         145764                    2
#           Austin Oasis                                    145834                    2
#           Balmoral Home                                   145796                    2
#           Alden North Shore                               145984                    2
#           SHERIDAN VILLAGE NURSING HOME                   No Match                  2
# Lake      Rolling Hills Manor                             145443                    2
# Vermilion Accolade Health Care of Danville                No Match                  2
# Cook      Citadel of Skokie                               145468                    2
#           Arbour Health Care Center                       146169                    2
#           Lakeview Nursing and Rehab                      145654                    2
# Marion    Bryan Manor                                     No Match                  1
# Lake      Sunrise of Buffalo Grove                        No Match                  1
# Marion    Cottages at Salem                               No Match                  1
# Lake      Storypoint Libertyville                         No Match                  1
#           Stonebridge of Gurnee                           No Match                  1
#           Springs of Vernon Hills Alzheimers Special Care No Match                  1
#           Sheridan at Green Oaks Senior Living            No Match                  1
#
#                                                                        facilities
# County    FacilityName2                                   CMS_ProvNum
# Cook      Aperion Care West Ridge                         145832                1
#           Lincolnwood Place                               145786                1
#           Symphony of South Shore                         145977                1
#           Symphony of Morgan Park                         145764                1
#           Austin Oasis                                    145834                1
#           Balmoral Home                                   145796                1
#           Alden North Shore                               145984                1
#           SHERIDAN VILLAGE NURSING HOME                   No Match              1
# Lake      Rolling Hills Manor                             145443                1
# Vermilion Accolade Health Care of Danville                No Match              1
# Cook      Citadel of Skokie                               145468                1
#           Arbour Health Care Center                       146169                1
#           Lakeview Nursing and Rehab                      145654                1
# Marion    Bryan Manor                                     No Match              1
# Lake      Sunrise of Buffalo Grove                        No Match              1
# Marion    Cottages at Salem                               No Match              1
# Lake      Storypoint Libertyville                         No Match              1
#           Stonebridge of Gurnee                           No Match              1
#           Springs of Vernon Hills Alzheimers Special Care No Match              1
#           Sheridan at Green Oaks Senior Living            No Match              1

# %%
outbreak_df.head(5)
# Out:
#   reporting_date County                   FacilityName  confirmed_cases  \
# 0     2021-01-15  Adams                       Chaddock               11
# 1     2021-01-15  Adams  Illinois Veterans Home Quincy              239
# 2     2021-01-15  Adams            Good Samaritan Home               57
# 3     2021-01-15  Adams     Adams Pointe Senior Living                4
# 4     2021-01-15  Adams                 Bradford Villa                8
#
#    deaths           ReportDate  status       CFR  outbreaks  \
# 0       0  2021-01-15T00:00:00    Open  0.000000          1
# 1      14  2021-01-15T00:00:00    Open  0.058577          1
# 2       1  2021-01-15T00:00:00    Open  0.017544          1
# 3       0  2021-01-15T00:00:00  Closed  0.000000          1
# 4       1  2021-01-15T00:00:00  Closed  0.125000          1
#
#                         county-facName CMS_ProvNum  Closed_Outbreaks  \
# 0                       ADAMS-CHADDOCK    No Match                 0
# 1  ADAMS-ILLINOIS VETERANS HOME QUINCY    No Match                 0
# 2            ADAMS-GOOD SAMARITAN HOME      145773                 0
# 3     ADAMS-ADAMS POINTE SENIOR LIVING    No Match                 1
# 4                 ADAMS-BRADFORD VILLA    No Match                 1
#
#    Open_Outbreaks                  FacilityName2
# 0               1                       Chaddock
# 1               1  Illinois Veterans Home Quincy
# 2               1            Good Samaritan Home
# 3               0     Adams Pointe Senior Living
# 4               0                 Bradford Villa

# %%
df_facilities.head(10)
# Out:
#                                                  ReportingDate  \
# County FacilityName2                 CMS_ProvNum
# Adams  Adams Pointe Senior Living    No Match       2021-01-15
#        Bickford Cottage              No Match       2021-01-15
#        Blessing Hospital SNU         No Match       2021-01-15
#        Bradford Villa                No Match       2021-01-15
#        Cedarhurst                    No Match       2021-01-15
#        Chaddock                      No Match       2021-01-15
#        Golden Good Shepperd Home     No Match       2021-01-15
#        Good Samaritan Home           145773         2021-01-15
#        Illinois Veterans Home Quincy No Match       2021-01-15
#        Quincy Terrace                No Match       2021-01-15
#
#                                                   confirmed_cases  deaths  \
# County FacilityName2                 CMS_ProvNum
# Adams  Adams Pointe Senior Living    No Match                   4       0
#        Bickford Cottage              No Match                   7       0
#        Blessing Hospital SNU         No Match                   5       0
#        Bradford Villa                No Match                  21       1
#        Cedarhurst                    No Match                  26       1
#        Chaddock                      No Match                  11       0
#        Golden Good Shepperd Home     No Match                  54       9
#        Good Samaritan Home           145773                    57       1
#        Illinois Veterans Home Quincy No Match                 239      14
#        Quincy Terrace                No Match                  16       1
#
#                                                        CFR  outbreaks  \
# County FacilityName2                 CMS_ProvNum
# Adams  Adams Pointe Senior Living    No Match     0.000000          1
#        Bickford Cottage              No Match     0.000000          1
#        Blessing Hospital SNU         No Match     0.000000          1
#        Bradford Villa                No Match     0.047619          2
#        Cedarhurst                    No Match     0.038462          1
#        Chaddock                      No Match     0.000000          1
#        Golden Good Shepperd Home     No Match     0.166667          1
#        Good Samaritan Home           145773       0.017544          1
#        Illinois Veterans Home Quincy No Match     0.058577          1
#        Quincy Terrace                No Match     0.062500          1
#
#                                                   Closed_Outbreaks  \
# County FacilityName2                 CMS_ProvNum
# Adams  Adams Pointe Senior Living    No Match                    1
#        Bickford Cottage              No Match                    0
#        Blessing Hospital SNU         No Match                    0
#        Bradford Villa                No Match                    1
#        Cedarhurst                    No Match                    1
#        Chaddock                      No Match                    0
#        Golden Good Shepperd Home     No Match                    1
#        Good Samaritan Home           145773                      0
#        Illinois Veterans Home Quincy No Match                    0
#        Quincy Terrace                No Match                    0
#
#                                                   Open_Outbreaks  facilities
# County FacilityName2                 CMS_ProvNum
# Adams  Adams Pointe Senior Living    No Match                  0           1
#        Bickford Cottage              No Match                  1           1
#        Blessing Hospital SNU         No Match                  1           1
#        Bradford Villa                No Match                  1           1
#        Cedarhurst                    No Match                  0           1
#        Chaddock                      No Match                  1           1
#        Golden Good Shepperd Home     No Match                  0           1
#        Good Samaritan Home           145773                    1           1
#        Illinois Veterans Home Quincy No Match                  1           1
#        Quincy Terrace                No Match                  1           1

# %%
# # display(df_facilities.reset_index().head(5))
# df_facilities.head(5)

# %%
df_facilities.reset_index().groupby(['CMS_ProvNum']).count().sort_values(by='County', ascending=False)
# Out:
#              County  FacilityName2  ReportingDate  confirmed_cases  deaths  \
# CMS_ProvNum
# No Match        978            978            978              978     978
# 145364            3              3              3                3       3
# 14E888            2              2              2                2       2
# 145609            2              2              2                2       2
# 145784            2              2              2                2       2
# ...             ...            ...            ...              ...     ...
# 145639            1              1              1                1       1
# 145638            1              1              1                1       1
# 145637            1              1              1                1       1
# 145636            1              1              1                1       1
# 140E170           1              1              1                1       1
#
#              CFR  outbreaks  Closed_Outbreaks  Open_Outbreaks  facilities
# CMS_ProvNum
# No Match     978        978               978             978         978
# 145364         3          3                 3               3           3
# 14E888         2          2                 2               2           2
# 145609         2          2                 2               2           2
# 145784         2          2                 2               2           2
# ...          ...        ...               ...             ...         ...
# 145639         1          1                 1               1           1
# 145638         1          1                 1               1           1
# 145637         1          1                 1               1           1
# 145636         1          1                 1               1           1
# 140E170        1          1                 1               1           1
#
# [509 rows x 10 columns]

# %%
df_facilities = df_facilities.reset_index()
s = df_facilities.CMS_ProvNum.value_counts()
dupNamesList = list(s.where((s > 1) & (s < 100)).dropna().keys())

# %%
s = df_facilities.CMS_ProvNum.value_counts()
dupNamesList = list(s.where((s > 1) & (s < 100)).dropna().keys())

# %%
dupFacNames_df = df_facilities[df_facilities['CMS_ProvNum'].isin(dupNamesList)].sort_values(by='CMS_ProvNum')
dupFacNames_df.to_csv('IL_dup_fac_names.csv')
dupFacNames_df
# Out:
#         County                              FacilityName2 CMS_ProvNum  \
# 782       Kane                       The Grove Fox Valley      145006
# 784       Kane                    The Grove of Fox Valley      145006
# 794   Kankakee            Citadel Care Center of Kankakee      145043
# 795   Kankakee                        Citadel of Kankakee      145043
# 1065   McHenry                    Cross Roads Care Center      145222
# ...        ...                                        ...         ...
# 328       Cook  Little Sisters of the Poor/St. Marys Home      146185
# 725       Kane            Alden Estates Courts of Huntley      146186
# 726       Kane            Alden Estates-Courts of Huntley      146186
# 1176    Peoria                  Sharon Healthcare Willows      14E888
# 1177    Peoria            Sharon Healthcare Willows South      14E888
#
#      ReportingDate  confirmed_cases  deaths       CFR  outbreaks  \
# 782     2021-01-15              169      24  0.142012          2
# 784     2021-01-15                7       0  0.000000          1
# 794     2021-01-15                5       0  0.000000          1
# 795     2021-01-15               80       2  0.025000          1
# 1065    2021-01-15               71      13  0.183099          1
# ...            ...              ...     ...       ...        ...
# 328     2021-01-15               61      13  0.213115          1
# 725     2021-01-15                9       0  0.000000          1
# 726     2021-01-15               48       2  0.041667          1
# 1176    2021-01-15              129       4  0.031008          1
# 1177    2021-01-15                4       1  0.250000          1
#
#       Closed_Outbreaks  Open_Outbreaks  facilities
# 782                  1               1           1
# 784                  1               0           1
# 794                  0               1           1
# 795                  0               1           1
# 1065                 1               0           1
# ...                ...             ...         ...
# 328                  1               0           1
# 725                  1               0           1
# 726                  0               1           1
# 1176                 0               1           1
# 1177                 1               0           1
#
# [77 rows x 11 columns]

# %% [markdown]
# # Convert Facility Sheet to CTP format

# %%
CTP_cols = ['ReportingDate', 'State', 'County', 
            'City',
            'FacilityName', 'TYPE',
            'CTP Facility Categorization',
            'State/Fed Regulated',
            'State Facility ID',
            'CMS Facility ID',
            'Date outbreak opened', 'Date outreak closed', 'Outbreak Status','Resident Census',
            
'TOTAL RESIDENT CASES', # 'Resident Positives ',
          'TOTAL Resident Probable Positives',
'TOTAL RESIDENT DEATHS', # 'Resident Deaths',
         'TOTAL Resident Probable Deaths',
'TOTAL STAFF CASES', #'Staff Positive',
         'TOTAL Staff Probable Positives',
'TOTAL STAFF DEATHS', #'TOTAL Staff Deaths',
         'TOTAL Staff Probable Deaths',
 'confirmed_cases',
 'TOTAL Resident/Staff Probable Positives',
 'deaths',
 'TOTAL Resident/Staff Probable Deaths',
 
'NEW RESIDENT CASES', #            'Resident Positives',
     'NEW Resident Probable Positives',
 'NEW RESIDENT DEATHS',
     'NEW Resident Probable Deaths',
 'NEW STAFF CASES',
     'NEW Staff Probable Positives',
 'NEW STAFF DEATHS',
     'NEW Staff Probable Deaths',
 'NEW Resident/Staff Positives',
 'NEW Resident/Staff Probable Positives',
 'NEW Resident/Staff Deaths',
 'NEW Resident/Staff Probable Deaths',
 'Residents Tested',
 'Staff Tested',
 'Personal Protective Equipment',
           'COMPLIANCE']

CTP_Blank_Cols = ['City',
             'TYPE',
            'CTP Facility Categorization',
            'State/Fed Regulated',
            'State Facility ID',
            'CMS Facility ID',
            'Date outbreak opened', 'Date outreak closed', 'Resident Census',
            
'TOTAL RESIDENT CASES', # 'Resident Positives ',
          'TOTAL Resident Probable Positives',
'TOTAL RESIDENT DEATHS', # 'Resident Deaths',
         'TOTAL Resident Probable Deaths',
'TOTAL STAFF CASES', #'Staff Positive',
         'TOTAL Staff Probable Positives',
'TOTAL STAFF DEATHS', #'TOTAL Staff Deaths',
         'TOTAL Staff Probable Deaths',

 'TOTAL Resident/Staff Probable Positives',

 'TOTAL Resident/Staff Probable Deaths',
 
'NEW RESIDENT CASES', #            'Resident Positives',
     'NEW Resident Probable Positives',
 'NEW RESIDENT DEATHS',
     'NEW Resident Probable Deaths',
 'NEW STAFF CASES',
     'NEW Staff Probable Positives',
 'NEW STAFF DEATHS',
     'NEW Staff Probable Deaths',
 'NEW Resident/Staff Positives',
 'NEW Resident/Staff Probable Positives',
 'NEW Resident/Staff Deaths',
 'NEW Resident/Staff Probable Deaths',
 'Residents Tested',
 'Staff Tested',
 'Personal Protective Equipment',
           'COMPLIANCE']

# %%
def open_closed(outbreaks):
    if outbreaks == 0:
        return 'Closed'
    else:
        return 'Open'
        
for col in CTP_Blank_Cols:
    df_facilities[col] = ''
df_facilities['Outbreak Status'] = df_facilities['Open_Outbreaks'].apply(open_closed) #TO FINISH
df_facilities['State'] = 'IL'
df_facilities['ReportingDate'] = reporting_date.replace('-', '')

# %%
df_facilities.rename(columns={'FacilityName2': 'FacilityName'}, inplace=True)
df_facilities[CTP_cols].to_csv('Reporting_data/IL_' + reporting_date + '_Facilities_LTC_data_vCTP.csv', index=False)

# %%
df_facilities.head()
# Out:
#   County                FacilityName CMS_ProvNum ReportingDate  \
# 0  Adams  Adams Pointe Senior Living    No Match      20210115
# 1  Adams            Bickford Cottage    No Match      20210115
# 2  Adams       Blessing Hospital SNU    No Match      20210115
# 3  Adams              Bradford Villa    No Match      20210115
# 4  Adams                  Cedarhurst    No Match      20210115
#
#    confirmed_cases  deaths       CFR  outbreaks  Closed_Outbreaks  \
# 0                4       0  0.000000          1                 1
# 1                7       0  0.000000          1                 0
# 2                5       0  0.000000          1                 0
# 3               21       1  0.047619          2                 1
# 4               26       1  0.038462          1                 1
#
#    Open_Outbreaks  facilities City TYPE CTP Facility Categorization  \
# 0               0           1
# 1               1           1
# 2               1           1
# 3               1           1
# 4               0           1
#
#   State/Fed Regulated State Facility ID CMS Facility ID Date outbreak opened  \
# 0
# 1
# 2
# 3
# 4
#
#   Date outreak closed Resident Census TOTAL RESIDENT CASES  \
# 0
# 1
# 2
# 3
# 4
#
#   TOTAL Resident Probable Positives TOTAL RESIDENT DEATHS  \
# 0
# 1
# 2
# 3
# 4
#
#   TOTAL Resident Probable Deaths TOTAL STAFF CASES  \
# 0
# 1
# 2
# 3
# 4
#
#   TOTAL Staff Probable Positives TOTAL STAFF DEATHS  \
# 0
# 1
# 2
# 3
# 4
#
#   TOTAL Staff Probable Deaths TOTAL Resident/Staff Probable Positives  \
# 0
# 1
# 2
# 3
# 4
#
#   TOTAL Resident/Staff Probable Deaths NEW RESIDENT CASES  \
# 0
# 1
# 2
# 3
# 4
#
#   NEW Resident Probable Positives NEW RESIDENT DEATHS  \
# 0
# 1
# 2
# 3
# 4
#
#   NEW Resident Probable Deaths NEW STAFF CASES NEW Staff Probable Positives  \
# 0
# 1
# 2
# 3
# 4
#
#   NEW STAFF DEATHS NEW Staff Probable Deaths NEW Resident/Staff Positives  \
# 0
# 1
# 2
# 3
# 4
#
#   NEW Resident/Staff Probable Positives NEW Resident/Staff Deaths  \
# 0
# 1
# 2
# 3
# 4
#
#   NEW Resident/Staff Probable Deaths Residents Tested Staff Tested  \
# 0
# 1
# 2
# 3
# 4
#
#   Personal Protective Equipment COMPLIANCE Outbreak Status State
# 0                                                   Closed    IL
# 1                                                     Open    IL
# 2                                                     Open    IL
# 3                                                     Open    IL
# 4                                                   Closed    IL

# %% [markdown]
# # Play Area

# %%
df = pd.DataFrame(ltc_data['LTC_Historical_Reported_Cases'])
df.sort_values(by=['reported_date'], inplace=True)
df['new_deaths']= df.deaths.diff()
df['new_confirmed_cases'] = df.confirmed_cases.diff()

# %%
chart_title = 'IL Cases by Week'
chart1 = alt.Chart(df).mark_bar().encode(
                     x=alt.X('yearmonthdate(reported_date):O', title='date', axis=alt.Axis(labelSeparation=10)),
                     y='new_confirmed_cases',
                     ).properties( width=400, height=400, title=chart_title)
chart_title = 'IL Deaths by Week'
chart2 = alt.Chart(df).mark_bar().encode(
                     x=alt.X('yearmonthdate(reported_date):O', title='date', axis=alt.Axis(labelSeparation=10)),
                     y='new_deaths',
                     ).properties( width=400, height=400, title=chart_title)
chart1 | chart2
# Out:
# alt.HConcatChart(...)
