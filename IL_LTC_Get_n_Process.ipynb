# %% [markdown]
# ### Doing
#  - [ ] Add CMS_IDs to Outbreaks and Facilities
#
# ### To Do
#  - [ ] Group Facilities by CMS_Provider_Num WHERE Available
#
# ### DONE
#  - [x] Separate funtions into separate Python files

# %%
import pandas as pd
import urllib3 as urllib
import urllib.request as urllib2
import json
import glob
import IPython.display

from Modules.IL_Functions import *

pd.options.display.max_columns = None

# %% [markdown]
# ## 1 - Get "Raw Data" from website and store in file

# %%
[reporting_date, ltc_data] = pull_IL_json_from_web()

# %%
# print('Source File: ' + str(json_file))
[reporting_date, summary, outbreak_df, df_facilities, df_county] = process_IL_dict(ltc_data, ltc_name2cms_id, display_dfs=False)
# Out:
# Date: 2021-01-08
# Cases: 67407
# Deaths: 8670
# Outbreaks: 1899
# Open Outbreaks: 1038
# Closed Outbreaks: 861
# Facilities: 1510

# %%
outbreak_df.groupby(['County', 'FacilityName']).sum()
# Out:
#                                             confirmed_cases  deaths       CFR  \
# County   FacilityName
# Adams    Adams Pointe Senior Living                       4       0  0.000000
#          Bickford Cottage (2)                             7       0  0.000000
#          Blessing Hospital SNU (2)                        3       0  0.000000
#          Bradford Villa                                   8       1  0.125000
#          Bradford Villa (2)                              13       0  0.000000
# ...                                                     ...     ...       ...
# Woodford Heritage Health El Paso                         46       9  0.195652
#          Snyder Village Assisted Living                   5       0  0.000000
#          Snyder Village Assisted Living                   2       0  0.000000
#          Snyder Village Health Center                    46      13  0.282609
#          The Loft Rehabilitation & Nursing                8       0  0.000000
#
#                                             outbreaks  Closed_Outbreaks  \
# County   FacilityName
# Adams    Adams Pointe Senior Living                 1                 1
#          Bickford Cottage (2)                       1                 0
#          Blessing Hospital SNU (2)                  1                 0
#          Bradford Villa                             1                 1
#          Bradford Villa (2)                         1                 0
# ...                                               ...               ...
# Woodford Heritage Health El Paso                    1                 0
#          Snyder Village Assisted Living             1                 0
#          Snyder Village Assisted Living             1                 1
#          Snyder Village Health Center               1                 0
#          The Loft Rehabilitation & Nursing          1                 0
#
#                                             Open_Outbreaks
# County   FacilityName
# Adams    Adams Pointe Senior Living                      0
#          Bickford Cottage (2)                            1
#          Blessing Hospital SNU (2)                       1
#          Bradford Villa                                  0
#          Bradford Villa (2)                              1
# ...                                                    ...
# Woodford Heritage Health El Paso                         1
#          Snyder Village Assisted Living                  1
#          Snyder Village Assisted Living                  0
#          Snyder Village Health Center                    1
#          The Loft Rehabilitation & Nursing               1
#
# [1533 rows x 6 columns]

# %%
df_facilities.sort_values(by='Open_Outbreaks', ascending=False).head(20)
# Out:
#                                                                    ReportingDate  \
# County    FacilityName2                                CMS_ProvNum
# Cook      Aperion Care West Ridge                      145832         2021-01-08
#           SHERIDAN VILLAGE NURSING HOME                No Match       2021-01-08
#           Balmoral Home                                145796         2021-01-08
# Macoupin  Carlinville Heritage Health                  145456         2021-01-08
# Cook      Austin Oasis                                 145834         2021-01-08
# Lake      Rolling Hills Manor                          145443         2021-01-08
# Cook      Alden North Shore                            145984         2021-01-08
#           Arbour Health Care Center                    146169         2021-01-08
#           Citadel of Skokie                            145468                    2
#           Franciscan Village                           146029                    2
#           Symphony of South Shore                      145977                    2
#           Symphony of Morgan Park                      145764                    2
# St. Clair Cedarhurst of Shiloh                         No Match                  1
#           Caseyville Care Center2                      145585                    1
#           Cedar Ridge2                                 No Match                  1
#           Cedarhurst of Shiloh2                        No Match                  1
#           Cerebral Palsy of Southwestern Illinois CILA No Match                  1
#
#                                                                     facilities
# County    FacilityName2                                CMS_ProvNum
# Cook      Aperion Care West Ridge                      145832                1
#           SHERIDAN VILLAGE NURSING HOME                No Match              1
#           Balmoral Home                                145796                1
# Macoupin  Carlinville Heritage Health                  145456                1
# Cook      Austin Oasis                                 145834                1
# Lake      Rolling Hills Manor                          145443                1
# Cook      Alden North Shore                            145984                1
#           Arbour Health Care Center                    146169                1
# Lake      Warren Barr North Shore                      145923                1
# Vermilion Accolade Health Care of Danville             No Match              1
# Cook      Lakeview Nursing and Rehab                   145654                1
#           Citadel of Skokie                            145468                1
#           Franciscan Village                           146029                1
#           Symphony of South Shore                      145977                1
#           Symphony of Morgan Park                      145764                1
# St. Clair Cedarhurst of Shiloh                         No Match              1
#           Caseyville Care Center2                      145585                1
#           Cedar Ridge2                                 No Match              1
#           Cedarhurst of Shiloh2                        No Match              1
#           Cerebral Palsy of Southwestern Illinois CILA No Match              1

# %%
outbreak_df.head(5)
# Out:
#   reporting_date County                   FacilityName  confirmed_cases  \
# 0     2021-01-08  Adams                       Chaddock               11
# 1     2021-01-08  Adams  Illinois Veterans Home Quincy              239
# 2     2021-01-08  Adams            Good Samaritan Home               49
# 3     2021-01-08  Adams     Adams Pointe Senior Living                4
# 4     2021-01-08  Adams                 Bradford Villa                8
#
#    deaths           ReportDate  status       CFR  outbreaks  \
# 0       0  2021-01-08T00:00:00    Open  0.000000          1
# 1       7  2021-01-08T00:00:00    Open  0.029289          1
# 2       1  2021-01-08T00:00:00    Open  0.020408          1
# 3       0  2021-01-08T00:00:00  Closed  0.000000          1
# 4       1  2021-01-08T00:00:00  Closed  0.125000          1
#
#                         county-facName CMS_ProvNum  Closed_Outbreaks  \
# 0                       ADAMS-CHADDOCK    No Match                 0
# 1  ADAMS-ILLINOIS VETERANS HOME QUINCY    No Match                 0
# 2            ADAMS-GOOD SAMARITAN HOME      145773                 0
# 3     ADAMS-ADAMS POINTE SENIOR LIVING    No Match                 1
# 4                 ADAMS-BRADFORD VILLA    No Match                 1
#
#    Open_Outbreaks                  FacilityName2
# 0               1                       Chaddock
# 1               1  Illinois Veterans Home Quincy
# 2               1            Good Samaritan Home
# 3               0     Adams Pointe Senior Living
# 4               0                 Bradford Villa

# %%
df_facilities.head(10)
# Out:
#                                                  ReportingDate  \
# County FacilityName2                 CMS_ProvNum
# Adams  Adams Pointe Senior Living    No Match       2021-01-08
#        Bickford Cottage              No Match       2021-01-08
#        Blessing Hospital SNU         No Match       2021-01-08
#        Bradford Villa                No Match       2021-01-08
#        Cedarhurst                    No Match       2021-01-08
#        Chaddock                      No Match       2021-01-08
#        Golden Good Shepperd Home     No Match       2021-01-08
#        Good Samaritan Home           145773         2021-01-08
#        Illinois Veterans Home Quincy No Match       2021-01-08
#        Quincy Terrace                No Match       2021-01-08
#
#                                                   confirmed_cases  deaths  \
# County FacilityName2                 CMS_ProvNum
# Adams  Adams Pointe Senior Living    No Match                   4       0
#        Bickford Cottage              No Match                   7       0
#        Blessing Hospital SNU         No Match                   3       0
#        Bradford Villa                No Match                  21       1
#        Cedarhurst                    No Match                  26       1
#        Chaddock                      No Match                  11       0
#        Golden Good Shepperd Home     No Match                  54       9
#        Good Samaritan Home           145773                    49       1
#        Illinois Veterans Home Quincy No Match                 239       7
#        Quincy Terrace                No Match                  16       1
#
#                                                        CFR  outbreaks  \
# County FacilityName2                 CMS_ProvNum
# Adams  Adams Pointe Senior Living    No Match     0.000000          1
#        Bickford Cottage              No Match     0.000000          1
#        Blessing Hospital SNU         No Match     0.000000          1
#        Bradford Villa                No Match     0.047619          2
#        Cedarhurst                    No Match     0.038462          1
#        Chaddock                      No Match     0.000000          1
#        Golden Good Shepperd Home     No Match     0.166667          1
#        Good Samaritan Home           145773       0.020408          1
#        Illinois Veterans Home Quincy No Match     0.029289          1
#        Quincy Terrace                No Match     0.062500          1
#
#                                                   Closed_Outbreaks  \
# County FacilityName2                 CMS_ProvNum
# Adams  Adams Pointe Senior Living    No Match                    1
#        Bickford Cottage              No Match                    0
#        Blessing Hospital SNU         No Match                    0
#        Bradford Villa                No Match                    1
#        Cedarhurst                    No Match                    1
#        Chaddock                      No Match                    0
#        Golden Good Shepperd Home     No Match                    1
#        Good Samaritan Home           145773                      0
#        Illinois Veterans Home Quincy No Match                    0
#        Quincy Terrace                No Match                    0
#
#                                                   Open_Outbreaks  facilities
# County FacilityName2                 CMS_ProvNum
# Adams  Adams Pointe Senior Living    No Match                  0           1
#        Bickford Cottage              No Match                  1           1
#        Blessing Hospital SNU         No Match                  1           1
#        Bradford Villa                No Match                  1           1
#        Cedarhurst                    No Match                  0           1
#        Chaddock                      No Match                  1           1
#        Golden Good Shepperd Home     No Match                  0           1
#        Good Samaritan Home           145773                    1           1
#        Illinois Veterans Home Quincy No Match                  1           1
#        Quincy Terrace                No Match                  1           1

# %%
display(df_facilities.reset_index().head(5))
df_facilities.head(5)
# Out:
#   County               FacilityName2 CMS_ProvNum ReportingDate  \
# 0  Adams  Adams Pointe Senior Living    No Match    2021-01-08
# 1  Adams            Bickford Cottage    No Match    2021-01-08
# 2  Adams       Blessing Hospital SNU    No Match    2021-01-08
# 3  Adams              Bradford Villa    No Match    2021-01-08
# 4  Adams                  Cedarhurst    No Match    2021-01-08
#
#    confirmed_cases  deaths       CFR  outbreaks  Closed_Outbreaks  \
# 0                4       0  0.000000          1                 1
# 1                7       0  0.000000          1                 0
# 2                3       0  0.000000          1                 0
# 3               21       1  0.047619          2                 1
# 4               26       1  0.038462          1                 1
#
#    Open_Outbreaks  facilities
# 0               0           1
# 1               1           1
# 2               1           1
# 3               1           1
# 4               0           1
#                                               ReportingDate  confirmed_cases  \
# County FacilityName2              CMS_ProvNum
# Adams  Adams Pointe Senior Living No Match       2021-01-08                4
#        Bickford Cottage           No Match       2021-01-08                7
#        Blessing Hospital SNU      No Match       2021-01-08                3
#        Bradford Villa             No Match       2021-01-08               21
#        Cedarhurst                 No Match       2021-01-08               26
#
#                                                deaths       CFR  outbreaks  \
# County FacilityName2              CMS_ProvNum
# Adams  Adams Pointe Senior Living No Match          0  0.000000          1
#        Bickford Cottage           No Match          0  0.000000          1
#        Blessing Hospital SNU      No Match          0  0.000000          1
#        Bradford Villa             No Match          1  0.047619          2
#        Cedarhurst                 No Match          1  0.038462          1
#
#                                                Closed_Outbreaks  \
# County FacilityName2              CMS_ProvNum
# Adams  Adams Pointe Senior Living No Match                    1
#        Bickford Cottage           No Match                    0
#        Blessing Hospital SNU      No Match                    0
#        Bradford Villa             No Match                    1
#        Cedarhurst                 No Match                    1
#
#                                                Open_Outbreaks  facilities
# County FacilityName2              CMS_ProvNum
# Adams  Adams Pointe Senior Living No Match                  0           1
#        Bickford Cottage           No Match                  1           1
#        Blessing Hospital SNU      No Match                  1           1
#        Bradford Villa             No Match                  1           1
#        Cedarhurst                 No Match                  0           1

# %%
df_facilities.reset_index().groupby(['CMS_ProvNum']).count().sort_values(by='County', ascending=False)
# Out:
#              County  FacilityName2  ReportingDate  confirmed_cases  deaths  \
# CMS_ProvNum
# No Match        963            963            963              963     963
# 145364            3              3              3                3       3
# 14E888            2              2              2                2       2
# 145609            2              2              2                2       2
# 145784            2              2              2                2       2
# ...             ...            ...            ...              ...     ...
# 145639            1              1              1                1       1
# 145638            1              1              1                1       1
# 145637            1              1              1                1       1
# 145636            1              1              1                1       1
# 140E170           1              1              1                1       1
#
#              CFR  outbreaks  Closed_Outbreaks  Open_Outbreaks  facilities
# CMS_ProvNum
# No Match     963        963               963             963         963
# 145364         3          3                 3               3           3
# 14E888         2          2                 2               2           2
# 145609         2          2                 2               2           2
# 145784         2          2                 2               2           2
# ...          ...        ...               ...             ...         ...
# 145639         1          1                 1               1           1
# 145638         1          1                 1               1           1
# 145637         1          1                 1               1           1
# 145636         1          1                 1               1           1
# 140E170        1          1                 1               1           1
#
# [509 rows x 10 columns]

# %%
df_facilities = df_facilities.reset_index()
s = df_facilities.CMS_ProvNum.value_counts()
dupNamesList = list(s.where((s > 1) & (s < 100)).dropna().keys())

# %%
s = df_facilities.CMS_ProvNum.value_counts()
dupNamesList = list(s.where((s > 1) & (s < 100)).dropna().keys())

# %%
dupFacNames_df = df_facilities[df_facilities['CMS_ProvNum'].isin(dupNamesList)].sort_values(by='CMS_ProvNum')
dupFacNames_df.to_csv('IL_dup_fac_names.csv')
dupFacNames_df
# Out:
#         County                              FacilityName2 CMS_ProvNum  \
# 776       Kane                       The Grove Fox Valley      145006
# 778       Kane                    The Grove of Fox Valley      145006
# 788   Kankakee            Citadel Care Center of Kankakee      145043
# 789   Kankakee                        Citadel of Kankakee      145043
# 1059   McHenry                    Cross Roads Care Center      145222
# ...        ...                                        ...         ...
# 327       Cook  Little Sisters of the Poor/St. Marys Home      146185
# 719       Kane            Alden Estates Courts of Huntley      146186
# 720       Kane            Alden Estates-Courts of Huntley      146186
# 1169    Peoria                  Sharon Healthcare Willows      14E888
# 1170    Peoria            Sharon Healthcare Willows South      14E888
#
#      ReportingDate  confirmed_cases  deaths       CFR  outbreaks  \
# 776     2021-01-08              168      24  0.142857          2
# 778     2021-01-08                7       0  0.000000          1
# 788     2021-01-08                5       0  0.000000          1
# 789     2021-01-08               80       2  0.025000          1
# 1059    2021-01-08               71      13  0.183099          1
# ...            ...              ...     ...       ...        ...
# 327     2021-01-08               61      13  0.213115          1
# 719     2021-01-08                9       0  0.000000          1
# 720     2021-01-08               48       2  0.041667          1
# 1169    2021-01-08              129       3  0.023256          1
# 1170    2021-01-08                4       1  0.250000          1
#
#       Closed_Outbreaks  Open_Outbreaks  facilities
# 776                  1               1           1
# 778                  1               0           1
# 788                  0               1           1
# 789                  0               1           1
# 1059                 1               0           1
# ...                ...             ...         ...
# 327                  1               0           1
# 719                  1               0           1
# 720                  0               1           1
# 1169                 0               1           1
# 1170                 1               0           1
#
# [77 rows x 11 columns]

# %% [markdown]
# # Convert Facility Sheet to CTP format

# %%
CTP_cols = ['ReportingDate', 'State', 'County', 
            'City',
            'FacilityName', 'TYPE',
            'CTP Facility Categorization',
            'State/Fed Regulated',
            'State Facility ID',
            'CMS Facility ID',
            'Date outbreak opened', 'Date outreak closed', 'Outbreak Status','Resident Census',
            
'TOTAL RESIDENT CASES', # 'Resident Positives ',
          'TOTAL Resident Probable Positives',
'TOTAL RESIDENT DEATHS', # 'Resident Deaths',
         'TOTAL Resident Probable Deaths',
'TOTAL STAFF CASES', #'Staff Positive',
         'TOTAL Staff Probable Positives',
'TOTAL STAFF DEATHS', #'TOTAL Staff Deaths',
         'TOTAL Staff Probable Deaths',
 'confirmed_cases',
 'TOTAL Resident/Staff Probable Positives',
 'deaths',
 'TOTAL Resident/Staff Probable Deaths',
 
'NEW RESIDENT CASES', #            'Resident Positives',
     'NEW Resident Probable Positives',
 'NEW RESIDENT DEATHS',
     'NEW Resident Probable Deaths',
 'NEW STAFF CASES',
     'NEW Staff Probable Positives',
 'NEW STAFF DEATHS',
     'NEW Staff Probable Deaths',
 'NEW Resident/Staff Positives',
 'NEW Resident/Staff Probable Positives',
 'NEW Resident/Staff Deaths',
 'NEW Resident/Staff Probable Deaths',
 'Residents Tested',
 'Staff Tested',
 'Personal Protective Equipment',
           'COMPLIANCE']

CTP_Blank_Cols = ['City',
             'TYPE',
            'CTP Facility Categorization',
            'State/Fed Regulated',
            'State Facility ID',
            'CMS Facility ID',
            'Date outbreak opened', 'Date outreak closed', 'Resident Census',
            
'TOTAL RESIDENT CASES', # 'Resident Positives ',
          'TOTAL Resident Probable Positives',
'TOTAL RESIDENT DEATHS', # 'Resident Deaths',
         'TOTAL Resident Probable Deaths',
'TOTAL STAFF CASES', #'Staff Positive',
         'TOTAL Staff Probable Positives',
'TOTAL STAFF DEATHS', #'TOTAL Staff Deaths',
         'TOTAL Staff Probable Deaths',

 'TOTAL Resident/Staff Probable Positives',

 'TOTAL Resident/Staff Probable Deaths',
 
'NEW RESIDENT CASES', #            'Resident Positives',
     'NEW Resident Probable Positives',
 'NEW RESIDENT DEATHS',
     'NEW Resident Probable Deaths',
 'NEW STAFF CASES',
     'NEW Staff Probable Positives',
 'NEW STAFF DEATHS',
     'NEW Staff Probable Deaths',
 'NEW Resident/Staff Positives',
 'NEW Resident/Staff Probable Positives',
 'NEW Resident/Staff Deaths',
 'NEW Resident/Staff Probable Deaths',
 'Residents Tested',
 'Staff Tested',
 'Personal Protective Equipment',
           'COMPLIANCE']

# %%
def open_closed(outbreaks):
    if outbreaks == 0:
        return 'Closed'
    else:
        return 'Open'
        
for col in CTP_Blank_Cols:
    df_facilities[col] = ''
df_facilities['Outbreak Status'] = df_facilities['Open_Outbreaks'].apply(open_closed) #TO FINISH
df_facilities['State'] = 'IL'
df_facilities['ReportingDate'] = reporting_date.replace('-', '')

# %%
df_facilities.rename(columns={'FacilityName2': 'FacilityName'}, inplace=True)
df_facilities[CTP_cols].to_csv('Reporting_data/IL_' + reporting_date + '_Facilities_LTC_data_vCTP.csv', index=False)

# %%
df_facilities.columns
# Out:
# Index(['County', 'FacilityName', 'CMS_ProvNum', 'ReportingDate',
#        'confirmed_cases', 'deaths', 'CFR', 'outbreaks', 'Closed_Outbreaks',
#        'Open_Outbreaks', 'facilities', 'City', 'TYPE',
#        'CTP Facility Categorization', 'State/Fed Regulated',
#        'State Facility ID', 'CMS Facility ID', 'Date outbreak opened',
#        'Date outreak closed', 'Resident Census', 'TOTAL RESIDENT CASES',
#        'TOTAL Resident Probable Positives', 'TOTAL RESIDENT DEATHS',
#        'TOTAL Resident Probable Deaths', 'TOTAL STAFF CASES',
#        'TOTAL Staff Probable Positives', 'TOTAL STAFF DEATHS',
#        'TOTAL Staff Probable Deaths',
#        'TOTAL Resident/Staff Probable Positives',
#        'TOTAL Resident/Staff Probable Deaths', 'NEW RESIDENT CASES',
#        'NEW Resident Probable Positives', 'NEW RESIDENT DEATHS',
#        'NEW Resident Probable Deaths', 'NEW STAFF CASES',
#        'NEW Staff Probable Positives', 'NEW STAFF DEATHS',
#        'NEW Staff Probable Deaths', 'NEW Resident/Staff Positives',
#        'NEW Resident/Staff Probable Positives', 'NEW Resident/Staff Deaths',
#        'NEW Resident/Staff Probable Deaths', 'Residents Tested',
#        'Staff Tested', 'Personal Protective Equipment', 'COMPLIANCE',
#        'Outbreak Status', 'State'],
#       dtype='object')

# %%
df_facilities
# Out:
#         County                       FacilityName CMS_ProvNum ReportingDate  \
# 0        Adams         Adams Pointe Senior Living    No Match      20210108
# 1        Adams                   Bickford Cottage    No Match      20210108
# 2        Adams              Blessing Hospital SNU    No Match      20210108
# 3        Adams                     Bradford Villa    No Match      20210108
# 4        Adams                         Cedarhurst    No Match      20210108
# ...        ...                                ...         ...           ...
# 1505  Woodford         El Paso Health Care Center    No Match      20210108
# 1506  Woodford            Heritage Health El Paso      145319      20210108
# 1507  Woodford     Snyder Village Assisted Living      145596      20210108
# 1508  Woodford       Snyder Village Health Center    No Match      20210108
# 1509  Woodford  The Loft Rehabilitation & Nursing    No Match      20210108
#
#       confirmed_cases  deaths       CFR  outbreaks  Closed_Outbreaks  \
# 0                   4       0  0.000000          1                 1
# 1                   7       0  0.000000          1                 0
# 2                   3       0  0.000000          1                 0
# 3                  21       1  0.047619          2                 1
# 4                  26       1  0.038462          1                 1
# ...               ...     ...       ...        ...               ...
# 1505               75       0  0.000000          1                 0
# 1506               46       9  0.195652          1                 0
# 1507                7       0  0.000000          2                 1
# 1508               46      13  0.282609          1                 0
# 1509                8       0  0.000000          1                 0
#
#       Open_Outbreaks  facilities City TYPE CTP Facility Categorization  \
# 0                  0           1
# 1                  1           1
# 2                  1           1
# 3                  1           1
# 4                  0           1
# ...              ...         ...  ...  ...                         ...
# 1505               1           1
# 1506               1           1
# 1507               1           1
# 1508               1           1
# 1509               1           1
#
#      State/Fed Regulated State Facility ID CMS Facility ID  \
# 0
# 1
# 2
# 3
# 4
# ...                  ...               ...             ...
# 1505
# 1506
# 1507
# 1508
# 1509
#
#      Date outbreak opened Date outreak closed Resident Census  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...                 ...             ...
# 1505
# 1506
# 1507
# 1508
# 1509
#
#      TOTAL RESIDENT CASES TOTAL Resident Probable Positives  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...                               ...
# 1505
# 1506
# 1507
# 1508
# 1509
#
#      TOTAL RESIDENT DEATHS TOTAL Resident Probable Deaths TOTAL STAFF CASES  \
# 0
# 1
# 2
# 3
# 4
# ...                    ...                            ...               ...
# 1505
# 1506
# 1507
# 1508
# 1509
#
#      TOTAL Staff Probable Positives TOTAL STAFF DEATHS  \
# 0
# 1
# 2
# 3
# 4
# ...                             ...                ...
# 1505
# 1506
# 1507
# 1508
# 1509
#
#      TOTAL Staff Probable Deaths TOTAL Resident/Staff Probable Positives  \
# 0
# 1
# 2
# 3
# 4
# ...                          ...                                     ...
# 1505
# 1506
# 1507
# 1508
# 1509
#
#      TOTAL Resident/Staff Probable Deaths NEW RESIDENT CASES  \
# 0
# 1
# 2
# 3
# 4
# ...                                   ...                ...
# 1505
# 1506
# 1507
# 1508
# 1509
#
#      NEW Resident Probable Positives NEW RESIDENT DEATHS  \
# 0
# 1
# 2
# 3
# 4
# ...                              ...                 ...
# 1505
# 1506
# 1507
# 1508
# 1509
#
#      NEW Resident Probable Deaths NEW STAFF CASES  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...             ...
# 1505
# 1506
# 1507
# 1508
# 1509
#
#      NEW Staff Probable Positives NEW STAFF DEATHS NEW Staff Probable Deaths  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...              ...                       ...
# 1505
# 1506
# 1507
# 1508
# 1509
#
#      NEW Resident/Staff Positives NEW Resident/Staff Probable Positives  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                                   ...
# 1505
# 1506
# 1507
# 1508
# 1509
#
#      NEW Resident/Staff Deaths NEW Resident/Staff Probable Deaths  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...                                ...
# 1505
# 1506
# 1507
# 1508
# 1509
#
#      Residents Tested Staff Tested Personal Protective Equipment COMPLIANCE  \
# 0
# 1
# 2
# 3
# 4
# ...               ...          ...                           ...        ...
# 1505
# 1506
# 1507
# 1508
# 1509
#
#      Outbreak Status State
# 0             Closed    IL
# 1               Open    IL
# 2               Open    IL
# 3               Open    IL
# 4             Closed    IL
# ...              ...   ...
# 1505            Open    IL
# 1506            Open    IL
# 1507            Open    IL
# 1508            Open    IL
# 1509            Open    IL
#
# [1510 rows x 48 columns]

# %% [markdown]
# # Play Area

# %%
this_week_df = pd.read_csv('Reporting_data/IL_' + reporting_date + '_Facilities_LTC_data_v4.csv')

# %%
last_week_df= pd.read_csv('Reporting_data/IL_' + '2020-12-11' + '_Facilities_LTC_data_v4.csv')

# %%
new_df = pd.merge(this_week_df, last_week_df,  how='left', on=['County', 'FacilityName'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-ebcf27f82b8a> in <module>
# ----> 1 new_df = pd.merge(this_week_df, last_week_df,  how='left', on=['County', 'FacilityName'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
#     654         # validate the merge keys dtypes. We may need to coerce
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1016                         right_keys.append(rk)
#    1017                     if lk is not None:
# -> 1018                         left_keys.append(left._get_label_or_level_values(lk))
#    1019                         join_names.append(lk)
#    1020                     else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1561             values = self.axes[axis].get_level_values(key)._values
#    1562         else:
# -> 1563             raise KeyError(key)
#    1564
#    1565         # Check for duplicates
#
# KeyError: 'FacilityName'

# %%
new_df['new_cases']= new_df['confirmed_cases_x'] - new_df['confirmed_cases_y']
new_df['new_deaths']= new_df['deaths_x'] - new_df['deaths_y']

# %%
new_df.columns

# %%
cols=['County', 'FacilityName', 'CMS_ProvNum_x',
       'confirmed_cases_x', 'deaths_x', 'confirmed_cases_y', 'deaths_y', 'new_cases', 'new_deaths']
new_df[cols].sort_values(by='new_cases', ascending=False).head(10)

# %%
new_df[cols].sort_values(by='new_deaths', ascending=False).head(10)

# %%
import re
regex = re.compile('\(\d\)')
a = 'adsds (3)'
regex.split(a)[0].strip()

# %%
regex.split(a)[0].strip

# %%
outbreak_df

# %%
# outbreak_df['Closed_Outbreaks'] = outbreak_df['status'].apply(lambda x: 1 if x == "Closed" else 0)
# outbreak_df['Open_Outbreaks'] = outbreak_df['status'].apply(lambda x: 1 if x == "Open" else 0)


# # V2 - Remove cases of duplicate Outbreaks where they append (#) to end of Facility name to allow proper aggregation at the facility level
# regex = re.compile('\(\d\)')
# outbreak_df['FacilityName2'] = outbreak_df['FacilityName'].apply(lambda x: regex.split(x)[0].strip())


# # Save and Display Facility data
# df_facilities = outbreak_df.groupby(['County', 'FacilityName2', 'CMS_ProvNum']).sum()

# %%
# a = df_facilities.sort_values(by=['FacilityName2'])

# %%
# a[350:400]

# %%
summary
