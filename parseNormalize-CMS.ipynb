# %% [markdown]
# # Parse data from Google Sheet for tab "normalized-cms"

# %% [markdown]
# ## Doing
#  - [ ] Merge Provider info with IL Facility CSV
# ## To Do's
#  - [ ] Check Normalized names in spreadsheet, seems not all names Normailized ex: "ACCOLADE HEALTHCARE" and "Accolade Healthcare"
#  - [ ] Print list of names that would match if Normailized - Try for each matched Fed ID - check Normalized Names, Facility Name and do lookup to see if matching Facility Names with different Facility Normailized
#  - [ ] Lookup from CMS data feed as opposed to the spreadsheet VLOOKUPs
#  - [ ] Rename columns to prefix with data source: CTP_LTC_ and CMS_
#  - [ ] define and add data quality checks on feeds (ex dup checks if not allowed, etc)
#  - [ ] Compare CMS stats just b4 Covid and now
#
# ## Done
#  - [x] Get Counts, Sums and Means by Ownership type and State to see if any State way better/worse based on Ownership Type
#  - [x] Get Counts, Sums and Means by Ownership type
#  - [x] Join CMS data to State LTC data into DF for Provider Info
#  - [x] Create Facility Name to Provider Number for State to CMS mapping.
#  - [x] Add "Facility Normalize Name" - which is the name used to match in CMS feed to get Federal Provider Number
#  - [x] Check for more than one "Normalized Name" for the same "Facility Name"

# %%
from gsheets import Sheets

import json
import pandas as pd
pd.options.display.max_columns = None

# %% [markdown]
# # Define Functions

# %%
def parse_noarmalized_cms_sheet (df):
    """ # Create DFs for:
        #   1 - no_matches: Lists of "Factility Names" and "Facility Names Normalized" that do not have a matching CMS entry in the normalized-cms sheet
        #   2 - dupNames: Dictionary of "Federal Provider Numbers" that map to list where there are more than one "Facility Name"
        #   3 - CMSID2FacName: Dictionary mapping "Facility Names" to "Federal Provider Numbers"
        #   4 - FacName2CMSId: Dictionary mapping "Federal Provider Numbers" to "Facility Names"
    """
    FacName2CMSId = {}
    CMSID2FacName = {} # Initialize No Match to empty list so can always use extend for this key
    no_matches = {'Facility Names': [],
                  'Facility Names Normalized': []} # List of "Facility Names" without matches in CMS data feed
    dupNames = {} # Dictionary of "Federal Provider Numbers" that have more than one "Facility Name" 
                  #  (ex: 146182': ['Alden Courts of Waterford', 'Alden of Waterford'],
                  #      '146186': ['Alden Estates Courts of Huntley',
                  #                 'Alden Estates-Courts of Huntley'],
                  #       '145872': ['Alden Long Grove Rehab & Health',
                  #                  'Alden of Long Grove Rehab and HCC'], )

    # For Each Federal Provder Number (CMS term) in Provide ID - CMS (CTP term)
    for Fed_Prov_Num in df['Provider ID - CMS'].unique():
        # Since the gsheets api appends comments to the cell value (which for the record can be a PAIN and POTENTIAL PROBLEM)
        #    We change the value to a more understandable "No Match"
        if Fed_Prov_Num[0:4] == "#N/A":
            no_matches['Facility Names'].extend(list(df[df['Provider ID - CMS'] == Fed_Prov_Num]['Facility Name'].unique()))
            no_matches['Facility Names Normalized'].extend(list(df[df['Provider ID - CMS'] == Fed_Prov_Num]['Facility Name Normalized'].unique()))
        else:
            CMSID2FacName[Fed_Prov_Num] = list(df[df['Provider ID - CMS'] == Fed_Prov_Num]['Facility Name'].unique())
            if len(CMSID2FacName[Fed_Prov_Num]) > 1:
                dupNames[Fed_Prov_Num] = CMSID2FacName[Fed_Prov_Num]

            for facilityName in CMSID2FacName[Fed_Prov_Num]:
                FacName2CMSId[facilityName] = Fed_Prov_Num

    no_matches['Facility Names'] = list(dict.fromkeys(no_matches['Facility Names']))
    no_matches['Facility Names Normalized'] = list(dict.fromkeys(no_matches['Facility Names Normalized']))
    return FacName2CMSId, CMSID2FacName, no_matches, dupNames

# %% [markdown]
# # Get Info From SpreadSheet

# %%
sheets = Sheets.from_files('credentials.json', '~/storage.json')

# %%
url = 'https://docs.google.com/spreadsheets/d/14V12Hmx5B3BXsEBklYzDVC3mbnRDPSqJdsXHdzmO6yI'
s = sheets.get(url)

# %%
ns_sheet = s.find('normalized-state')
norm_df = ns_sheet.to_frame()
norm_df = norm_df.assign(FacilityNameNormalizedUCase = lambda x: (x['Facility Name'].str.upper()))

[FacName2CMSId, CMSID2FacName, no_matches, dupNames] = parse_noarmalized_cms_sheet(norm_df)

with open("IL_FacilityName_to_CMS_ID.json", "w") as outfile:  
    json.dump(FacName2CMSId, outfile)

# %%
# Get Quick Stats on number of names
print("Unique Facility Name count: " + str(len(norm_df['Facility Name'].unique())))
print("Unique Facility Name UPPER count: " + str(len(norm_df['Facility Name'].str.upper().unique())))
print("Unique Facility Normalized count: " + str(len(norm_df['Facility Name Normalized'].unique())))
print("Unique Facility Normalized UPPER count: " + str(len(norm_df['Facility Name Normalized'].str.upper().unique())))
print("Facilites with no match in CMS: ", len(no_matches))
print("Number of CMS entries matched to Federal Provider Number: ", len(CMSID2FacName))
print('"Federal Provider Numbers" that have more than one "Facility Name": ', len(dupNames))
# Out:
# Unique Facility Name count: 1196
# Unique Facility Name UPPER count: 1183
# Unique Facility Normalized count: 2060
# Unique Facility Normalized UPPER count: 1268
# Facilites with no match in CMS:  2
# Number of CMS entries matched to Federal Provider Number:  527
# "Federal Provider Numbers" that have more than one "Facility Name":  41

# %% [markdown]
# # Load CMS data

# %%
# added engine='python' because c engine does not support skipfooter
#cms_df = pd.read_csv('../CMS NursingHome Data/2013-07-01/ProviderInfo.csv', skipfooter=1, engine='python')
cms_df = pd.read_csv('../CMS NursingHome Data/2020-11-27/ProviderInfo_Download.csv', skipfooter=1, engine='python')
cms_df

# %%
merged_df = pd.merge(norm_df, cms_df, left_on='Provider ID - CMS',  right_on='PROVNUM', how='left')
merged_df

# %%
cols = ['PROVNUM', 'PROVNAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP', 'PHONE',
        'COUNTY_SSA', 'County_name', 'OWNERSHIP', 'BEDCERT', 'RESTOT', 'CERTIFICATION',
        'LBN',  'Overall_Rating', 'overall_rating_fn', 'INHOSP', 'INCIDENT_CNT', 'CMPLNT_CNT', 'FINE_CNT',
        'FINE_TOT', 'PAYDEN_CNT', 'TOT_PENLTY_CNT', 'FILEDATE']
        
#        'restot_fn', 'INHOSP', 'PARTICIPATION_DATE',
#        'CCRC_FACIL', 'SFFStatus', 'ABUSE_ICON', 'OldSurvey', 'CHOW_LAST_12MOS',
#        'RESFAMCOUNCIL', 'SPRINKLER_STATUS', 'Overall_Rating',
#        'overall_rating_fn', 'SURVEY_RATING', 'survey_rating_fn',
#        'Quality_Rating', 'quality_rating_fn', 'LS_Quality_Rating',
#        'LS_quality_rating_fn', 'SS_Quality_Rating', 'SS_quality_rating_fn',
#        'Staffing_Rating', 'staffing_rating_fn', 'RN_staffing_rating',
#        'RN_staffing_rating_fn', 'STAFFING_FLAG', 'PT_STAFFING_FLAG', 'AIDHRD',
#        'VOCHRD', 'RNHRD', 'TOTLICHRD', 'TOTHRD', 'PTHRD', 'CM_AIDE', 'CM_LPN',
#        'CM_RN', 'CM_TOTAL', 'ADJ_AIDE', 'ADJ_LPN', 'ADJ_RN', 'ADJ_TOTAL',
#        'WEIGHTED_ALL_CYCLES_SCORE', 'INCIDENT_CNT', 'CMPLNT_CNT', 'FINE_CNT',
#        'FINE_TOT', 'PAYDEN_CNT', 'TOT_PENLTY_CNT', 'FILEDATE']
cms_df.columns
cms_df[cols].head()

# %%
# Analysis by Ownership
cols = ['PROVNUM',  
        'OWNERSHIP', 'BEDCERT', 'RESTOT',   'Overall_Rating','INCIDENT_CNT', 'CMPLNT_CNT', 'FINE_CNT',
        'FINE_TOT', 'PAYDEN_CNT', 'TOT_PENLTY_CNT']
        
print("=== MEAN ====")
display(cms_df.groupby(['OWNERSHIP'])[cols].mean())
print("=== SUM ====")
display(cms_df.groupby(['OWNERSHIP'])[cols].sum())
print("=== Count ====")
display(cms_df.groupby(['OWNERSHIP'])[cols].count())

# %%
print(len(cms_df))
len(cms_df.PROVNUM.unique())

# %% [markdown]
# # 2013-07-01 Data

# %%
cms_df_2013 = pd.read_csv('../CMS NursingHome Data/2013-07-01/ProviderInfo.csv', skipfooter=1, engine='python')
# Analysis by Ownership
# cols = ['PROVNUM',  
#         'OWNERSHIP', 'BEDCERT', 'RESTOT',   'Overall_Rating','INCIDENT_CNT', 'CMPLNT_CNT', 'FINE_CNT',
#         'FINE_TOT', 'PAYDEN_CNT', 'TOT_PENLTY_CNT']
cols=['Federal Provider Number', 
#        'Provider Name', 'Provider Address',
#        'Provider City', 'Provider State', 'Provider Zip Code',
#        'Provider SSA County Code', 'Provider County Name', 
      'Ownership Type',
       'Number of Certified Beds', 'Number of Residents in Certified Beds',
#        'Provider Type', 'Provider Resides in Hospital', 'Legal Business Name',
#        'Date First Approved to Provide Medicare and Medicaid services',
#        'Continuing Care Retirement Community', 'Special Focus Facility',
#        'Provider Changed Ownership in Last 12 Months',
#        'With a Resident and Family Council',
#        'Automatic Sprinkler Systems in All Required Areas', 'Overall Rating',
#        'Overall Rating Footnote', 'Health Inspection Rating',
#        'Health Inspection Rating Footnote', 'QM Rating', 'QM Rating Footnote',
#        'Staffing Rating', 'Staffing Rating Footnote', 'RN Staffing Rating',
#        'RN Staffing Rating Footnote', 'Reported Staffing Footnote',
#        'Physical Therapist Staffing Footnote',
#        'Reported CNA Staffing Hours per Resident per Day',
#        'Reported LPN Staffing Hours per Resident per Day',
#        'Reported RN Staffing Hours per Resident per Day',
#        'Reported Licensed Staffing Hours per Resident per Day',
#        'Reported Total Nurse Staffing Hours per Resident per Day',
#        'Reported Physical Therapist Staffing Hours per Resident Per Day',
#        'Expected CNA Staffing Hours per Resident per Day',
#        'Expected LPN Staffing Hours per Resident per Day',
#        'Expected RN Staffing Hours per Resident per Day',
#        'Expected Total Nurse Staffing Hours per Resident per Day',
#        'Adjusted CNA Staffing Hours per Resident per Day',
#        'Adjusted LPN Staffing Hours per Resident per Day',
#        'Adjusted RN Staffing Hours per Resident per Day',
#        'Adjusted Total Nurse Staffing Hours per Resident per Day',
#        'Cycle 1 Total Number of Health Deficiencies',
#        'Cycle 1 Number of Standard Health Deficiencies',
#        'Cycle 1 Number of Complaint Health Deficiencies',
#        'Cycle 1 Health Deficiency Score',
#        'Cycle 1 Standard Survey Health Date',
#        'Cycle 1 Number of Health Revisits', 'Cycle 1 Health Revisit Score',
#        'Cycle 1 Total Health Score',
#        'Cycle 2 Total Number of Health Deficiencies',
#        'Cycle 2 Number of Standard Health Deficiencies',
#        'Cycle 2 Number of Complaint Health Deficiencies',
#        'Cycle 2 Health Deficiency Score',
#        'Cycle 2 Standard Health Survey Date',
#        'Cycle 2 Number of Health Revisits', 'Cycle 2 Health Revisit Score',
#        'Cycle 2 Total Health Score',
#        'Cycle 3 Total Number of Health Deficiencies',
#        'Cycle 3 Number of Standard Health Deficiencies',
#        'Cycle 3 Number of Complaint Health Deficiencies',
#        'Cycle 3 Health Deficiency Score',
#        'Cycle 3 Standard Health Survey Date',
#        'Cycle 3 Number of Health Revisits', 'Cycle 3 Health Revisit Score',
#        'Cycle 3 Total Health Score', 'Total Weighted Health Survey Score',
       'Number of Facility Reported Incidents',
       'Number of Substantiated Complaints', 'Number of Fines',
       'Total Amount of Fines in Dollars', 'Number of Payment Denials',
       'Total Number of Penalties', 'Location', 'Processing Date']
print("=== MEAN ====")
display(cms_df_2013.groupby(['Ownership Type'])[cols].mean())
print("=== SUM ====")
display(cms_df_2013.groupby(['Ownership Type'])[cols].sum())
print("=== Count ====")
display(cms_df_2013.groupby(['Ownership Type'])[cols].count())

# %%
cms_df_2013.columns

# %% [markdown]
# # Get Counts, Sums and Means by Ownership type and State
#  - to see if any State way better/worse based on Ownership Type

# %%
# Analysis by Ownership
cols = ['PROVNUM',  
        'OWNERSHIP', 'BEDCERT', 'RESTOT', 'INCIDENT_CNT', 'CMPLNT_CNT', 'FINE_CNT',
        'FINE_TOT', 'PAYDEN_CNT', 'TOT_PENLTY_CNT']
        
print("=== MEAN ====")
cms_df.groupby(['STATE', 'OWNERSHIP'])[cols].mean().to_csv('Reporting_data/CMS_Stats_2020-11-27_means.csv')
display(cms_df.groupby(['STATE', 'OWNERSHIP'])[cols].mean())
print("=== SUM ====")
cms_df.groupby(['STATE', 'OWNERSHIP'])[cols].sum().to_csv('Reporting_data/CMS_Stats_2020-11-27_sums.csv')
display(cms_df.groupby(['STATE', 'OWNERSHIP'])[cols].sum())
print("=== Count ====")
cms_df.groupby(['STATE', 'OWNERSHIP'])[cols].count().to_csv('Reporting_data/CMS_Stats_2020-11-27_counts.csv')
display(cms_df.groupby(['STATE', 'OWNERSHIP'])[cols].count())

# %%
cms_df.columns

# %% [markdown]
# # Play Area

# %%
# ToDO - Check Normalized names in spreadsheet, seems not all names Normailized ex: "ACCOLADE HEALTHCARE" and "Accolade Healthcare"
display(no_matches['Facility Names'][0:10])
display(no_matches['Facility Names Normalized'][0:10])

# %%
norm_df.head()

# %%
# Create DFs for:
#   1 - no_matches: Lists of "Factility Names" and "Facility Names Normalized" that do not have a matching CMS entry in the normalized-cms sheet
#   2 - dupNames: Dictionary of "Federal Provider Numbers" that map to list where there are more than one "Facility Name"
#   3 - CMSID2FacName: Dictionary mapping "Facility Names" to "Federal Provider Numbers"
#   4 - FacName2CMSId: Dictionary mapping "Federal Provider Numbers" to "Facility Names"

FacName2CMSId = {}
CMSID2FacName = {} # Initialize No Match to empty list so can always use extend for this key
no_matches = {'Facility Names': [],
              'Facility Names Normalized': []} # List of "Facility Names" without matches in CMS data feed
dupNames = {} # Dictionary of "Federal Provider Numbers" that have more than one "Facility Name" 
              #  (ex: 146182': ['Alden Courts of Waterford', 'Alden of Waterford'],
              #      '146186': ['Alden Estates Courts of Huntley',
              #                 'Alden Estates-Courts of Huntley'],
              #       '145872': ['Alden Long Grove Rehab & Health',
              #                  'Alden of Long Grove Rehab and HCC'], )

# For Each Federal Provder Number (CMS term) in Provide ID - CMS (CTP term)
for Fed_Prov_Num in norm_df['Provider ID - CMS'].unique():
    # Since the gsheets api appends comments to the cell value (which for the record can be a PAIN and POTENTIAL PROBLEM)
    #    We change the value to a more understandable "No Match"
    if Fed_Prov_Num[0:4] == "#N/A":
        no_matches['Facility Names'].extend(list(norm_df[norm_df['Provider ID - CMS'] == Fed_Prov_Num]['Facility Name'].unique()))
        no_matches['Facility Names Normalized'].extend(list(norm_df[norm_df['Provider ID - CMS'] == Fed_Prov_Num]['Facility Name Normalized'].unique()))
    else:
        CMSID2FacName[Fed_Prov_Num] = list(norm_df[norm_df['Provider ID - CMS'] == Fed_Prov_Num]['Facility Name'].unique())
        if len(CMSID2FacName[Fed_Prov_Num]) > 1:
            dupNames[Fed_Prov_Num] = CMSID2FacName[Fed_Prov_Num]
            
        for facilityName in CMSID2FacName[Fed_Prov_Num]:
            FacName2CMSId[facilityName] = Fed_Prov_Num
                              
no_matches['Facility Names'] = list(dict.fromkeys(no_matches['Facility Names']))
no_matches['Facility Names Normalized'] = list(dict.fromkeys(no_matches['Facility Names Normalized']))

# %%
norm_df[['County', 'Facility Name', 'Provider ID - CMS']].dropna()
# Out:
#       County                                Facility Name  \
# 1     DUPAGE             Abbington Rehab & Nursing Center
# 3       COOK                         Abington of Glenview
# 5       FORD                          Accolade Healthcare
# 7       FORD       Accolade Healthcare of Paxton on Pells
# 9       FORD  Accolade Healthcare of Paxton Senior Living
# ...      ...                                          ...
# 2382    COOK                                Winston Manor
# 2385    COOK                  Woodbridge Nursing Pavilion
# 2387  DUPAGE           Wynscape Health and Rehabilitation
# 2388  DUPAGE           Wynscape Health and Rehabilitation
# 2389  DUPAGE           Wynscape Health and Rehabilitation
#
#                                       Provider ID - CMS
# 1                                                146065
# 3                                                145683
# 5     #N/A (Did not find value 'ACCOLADE HEALTHCARE'...
# 7                                                145603
# 9                                                145449
# ...                                                 ...
# 2382                                            140E170
# 2385                                             145792
# 2387                                             145213
# 2388                                             145213
# 2389                                             145213
#
# [1208 rows x 3 columns]

# %%
CMSID2FacName
# Out:
# {'146065': ['Abbington Rehab & Nursing Center'],
#  '145683': ['Abington of Glenview'],
#  '145603': ['Accolade Healthcare of Paxton on Pells'],
#  '145449': ['Accolade Healthcare of Paxton Senior Living'],
#  '145724': ['ADDOLORATA VILLA'],
#  '145998': ['Alden', 'Alden Estates Des Plaines'],
#  '146183': ['Alden Courts of Shorewood'],
#  '146182': ['Alden Courts of Waterford', 'Alden of Waterford'],
#  '145142': ['Alden Debes Rehab Inc'],
#  '146186': ['Alden Estates Courts of Huntley',
#   'Alden Estates-Courts of Huntley'],
#  '145557': ['Alden Estates of Barrington'],
#  '145907': ['Alden Estates of Evanston'],
#  '145582': ['Alden Estates of Naperville'],
#  '145888': ['Alden Estates of Northmoor'],
#  '145963': ['Alden Estates of Orland Park'],
#  '146153': ['Alden Estates of Shorewood'],
#  '145869': ['Alden Estates of Skokie'],
#  '146008': ['Alden Gardens of Waterford'],
#  '145450': ['Alden Lakeland'],
#  '145126': ['Alden Lincoln Park Rehab'],
#  '145872': ['Alden Long Grove Rehab & Health',
#   'Alden of Long Grove Rehab and HCC'],
#  '145984': ['Alden North Shore'],
#  '145259': ['Alden Park Strathmoor'],
#  '145403': ['Alden PoplarCreek'],
#  '145688': ['Alden Princeton Rehab & Health'],
#  '145453': ['Alden Terrace of McHenry'],
#  '145736': ['Alden Town Manor Rehabilitation & Health Care Cent'],
#  '145379': ['Alden Valley Ridge'],
#  '145429': ['Alden Wentworth  Rehab & Healthcare Center',
#   'Alden Wentworth Rehab & Healthcare Center'],
#  '146052': ['Alhambra Rehab and Healthcare'],
#  '14A057': ['All American Nursing Home'],
#  '145770': ['Allure of Mount Carroll'],
#  '146066': ['Alpine Fireside Health Center'],
#  '145121': ['Alton Memorial Rehab and Therapy'],
#  '145343': ['Ambassador Nursing'],
#  '145908': ['Amberwood', 'Amberwood Care Center'],
#  '146112': ['Aperion Care Bradley'],
#  '145913': ['Aperion Care Burbank'],
#  '145160': ['Aperion Care Capitol'],
#  '145180': ['Aperion Care Chicago Heights'],
#  '145877': ['Aperion Care Dolton'],
#  '145740': ['Aperion Care Elgin'],
#  '146058': ['Aperion Care Evanston'],
#  '146000': ['Aperion Care Fairfield'],
#  '145969': ['Aperion Care Forest Park'],
#  '145936': ['Aperion Care Highwood', 'APERION CARE HIGHWOOD'],
#  '146001': ['Aperion Care International of Chicago'],
#  '145928': ['Aperion Care Jacksonville'],
#  '145295': ['Aperion Care Marseilles'],
#  '145947': ['Aperion Care Midlothian'],
#  '145197': ['Aperion Care Oak Lawn'],
#  '145811': ['Aperion Care Peoria Heights'],
#  '145658': ['Aperion Care Plum Grove'],
#  '145486': ['Aperion Care Spring Valley'],
#  '14E847': ['Aperion Care Springfield'],
#  '145857': ['Aperion Care St Elmo'],
#  '145830': ['Aperion Care West Chicago'],
#  '145832': ['Aperion Care West Ridge'],
#  '145437': ['Aperion Care- Princeton'],
#  '145248': ['Aperion Morton'],
#  '145316': ['Aperion Wilmington'],
#  '145704': ['Apostolic Christian Home of Roanoke'],
#  '145436': ['Apostolic Christian Restmor'],
#  '145933': ['Apostolic Christian Skyline'],
#  '146169': ['Arbour Health Care Center'],
#  '145753': ['Arcadia Care of Danville'],
#  '146050': ['Arcola Health Care'],
#  '145358': ['Arista Healthcare Naperville'],
#  '146187': ['Asbury Court Senior Living'],
#  '146170': ['Asbury Gardens'],
#  '146085': ['Ascension Presence Merkle Knipprath'],
#  '145563': ['Ascension St Anne Center'],
#  '14E361': ['Aspen Rehab'],
#  '145634': ['Astoria Place of Chicago'],
#  '145479': ['Atrium Health Care Center'],
#  '145136': ['Auburn Rehab and Healthcare Center'],
#  '145834': ['Austin Oasis'],
#  '145581': ['Autumn Meadows'],
#  '145699': ['Avantara Elgin', 'Avantara of Elgin'],
#  '145734': ['Avantara Evergreen Park'],
#  '145868': ['Avantara Long Grove'],
#  '145667': ['Avantara Park Ridge'],
#  '145601': ['Aviston Countryside Manor'],
#  '146181': ['Avondale Estates of Elgin'],
#  '145796': ['Balmoral Home'],
#  '146051': ['Barry Community Care'],
#  '140E96': ['Batavia Rehab', 'Batavia Rehabilitation Center'],
#  '145776': ['Beacon Care Center'],
#  '145522': ['Beacon Hill Lombard'],
#  '145538': ['Beecher Manor'],
#  '145198': ['Bella Terra Morton Grove'],
#  '145701': ['Bella Terra Streamwood'],
#  '145835': ['Bella Terra Wheeling'],
#  '145549': ['Bellhaven Nursing and Rehabilitation'],
#  '146121': ['Benton Rehab and Nusing'],
#  '146013': ['Berkeley Nursing and Rehabilitation Center'],
#  '145958': ['Bethany Rehab and Health Care Center #2',
#   'Bethany Rehabilitation and Health Care Center'],
#  '145844': ['Bethesda Rehab and Senior Care'],
#  '14E701': ['Big Meadows Nursing Home'],
#  '145532': ['Birchwood Plaza Nursing-Rehab'],
#  '145610': ['Bloomington Rehabilitation and Healthcare Center'],
#  '145527': ['Brandel Care Center'],
#  '145410': ['Breese Nursing Home'],
#  '145864': ['Bria Forest Edge'],
#  '145668': ['BRIA of Belleville'],
#  '145613': ['Bria of Cahokia'],
#  '145898': ['BRIA of Chicago Heights'],
#  '146067': ['Bria of Geneva'],
#  '145650': ['Bria of Palos Hills'],
#  '145405': ['Bria of Westmont'],
#  '145784': ['Bria Place', 'Bria Place of Indian Head Park'],
#  '145735': ['Bria River Oaks'],
#  '145208': ['Bridgeview HC'],
#  '145420': ['Bridgeway of Bensenville'],
#  '146094': ['Brookdale Burr Ridge'],
#  '146061': ['Brookdale Lisle'],
#  '145852': ['Brookdale Prospect Heights'],
#  '145285': ['Buckingham Pavilion'],
#  '145211': ['Burbank Rehab - Vera Care Stickney',
#   'Burbank Rehabilitation Center'],
#  '145219': ['Burgess Square Healthcare & Rehab Center'],
#  '145625': ['California Gardens Nursing and Rehabilitation Cent'],
#  '145846': ['Care Center at Center Grove'],
#  '145456': ['Carlinville Heritage Health'],
#  '145454': ['Carlinville Rehabilitation and Health Care Center'],
#  '145679': ['Carlton at the Lake'],
#  '145729': ['Carlyle HealthCare Center', 'Carlyle Healthcare Center'],
#  '146124': ['Carmi Manor'],
#  '145585': ['CASEYVILLE CARE CENTER', 'Caseyville Care Center2'],
#  '145571': ['Cedar Ridge'],
#  '145680': ['Centennial Care Center'],
#  '146062': ['Center Home for Hispanic Elderly'],
#  '145853': ['Central Baptist Village'],
#  '145648': ['Central Nursing Home'],
#  '145666': ['Centralia Manor'],
#  '145670': ['Chalet Living and Rehab', 'Chalet Living And Rehab Center'],
#  '145439': ['Champaign Urbana Nursing and Rehab',
#   'Champaign-Urbana Nursing and Rehab'],
#  '145636': ['Charleston Rehab and Healthcare'],
#  '145614': ['Chateau Center Nursing & Rehabilitation'],
#  '145639': ['Chicago Ridge Nursing and Rehab'],
#  '145430': ['Christian Nursing Home'],
#  '146131': ['Cisne Rehab and Health Care Center'],
#  '145043': ['Citadel Care Center of Kankakee', 'Citadel of Kankakee'],
#  '145004': ['Citadel of Elgin'],
#  '145982': ['Citadel of Northbrook'],
#  '145468': ['Citadel of Skokie'],
#  '145278': ['Citadel of Sterling'],
#  '145932': ['Citadel of Wilmette'],
#  '145850': ['City View Multi Care Center'],
#  '145434': ['Claridge Health Center'],
#  '145507': ['Clark Manor'],
#  '146025': ['Clinton Manor Living Facility'],
#  '145438': ['Collinsville Rehabilitation and Healthcare'],
#  '145183': ['Colonial Manor'],
#  '146164': ['Community Care Nursing Home'],
#  '146154': ['Concordia Village Senior'],
#  '145730': ['Continental Nursing and Rehabilitation Center'],
#  '145972': ['Cor Mariae'],
#  '145993': ['Coulterville Rehabilitation & Health Care Center'],
#  '145708': ['Country Health & Rehab', 'Country Health and Rehab'],
#  '145798': ['Countryside Nursing and Rehab Center'],
#  '146080': ['Countryview Care Center of Macomb'],
#  '140E178': ['Crestwood Terrace'],
#  '145222': ['Cross Roads Care Center', 'Crossroads Care Center'],
#  '145257': ['Crystal Pines Rehabilitation & Hlth Care Facility'],
#  '145547': ['DeKalb County Rehab and Nursing'],
#  '145122': ['Dobson Plaza'],
#  '145247': ['Doctors Nursing and Rehab Center'],
#  '145980': ['Dunham Rehab & Healthcare'],
#  '145050': ['DuPage Care Center'],
#  '146069': ['East Bank Center'],
#  '145384': ['Eden Village Care Center'],
#  '145555': ['Edwardsville Care Center'],
#  '145890': ['Eldorado Rehab and Healthcare'],
#  '145484': ['Elevate Care Chicago North'],
#  '145415': ['Elevate Care Irving Park'],
#  '145662': ['Elevate Care Niles'],
#  '145171': ['Elevate Care Northbrook'],
#  '145304': ['Elevate Care Riverwoods'],
#  '145669': ['Elevate Care Waukegan', 'ELEVATE CARE WAUKEGAN'],
#  '146176': ['Elevate Saint Andrew'],
#  '145858': ['Elmwood Nursing and Rehab'],
#  '145663': ['Elmwood Terrace'],
#  '145828': ['Estates of Hyde Park'],
#  '146095': ['Evenglow Lodge'],
#  '145917': ['Fair Oaks Health Care Center'],
#  '145552': ['Fairfield Memorial Hospital'],
#  '14E345': ['Fairhaven Christian Retirement Center'],
#  '145422': ['Fairhavens Senior Living'],
#  '145867': ['Fairmont Care'],
#  '146060': ['Faith Countryside'],
#  '145404': ['Farmington County Manor'],
#  '145791': ['Fireside House of Centralia'],
#  '145624': ['Flora Gardens'],
#  '146127': ['Florence Nursing Home'],
#  '145937': ['Forest City Rehab and Nursing'],
#  '145752': ['Forestview Rehabilitation & Nursing Center'],
#  '146167': ['Foster Health & Rehab'],
#  '145821': ['Fox River Rehab and Healthcare'],
#  '146029': ['Franciscan Village', 'Franciscan Village - Mother Teresa House'],
#  '140E213': ['Frankfort Terrace'],
#  '145200': ['Franklin Grove Living and Rehabilitation'],
#  '145515': ['Freeburg Care Center'],
#  '146099': ['Friendship Manor'],
#  '145341': ['Friendship Village LTC'],
#  '146140': ['Galena Stauss Nursing Home'],
#  '145926': ['Gardenview Manor'],
#  '145781': ['Generations at Applewood'],
#  '145419': ['Generations at Elmwood Park'],
#  '145719': ['Generations at Lincoln'],
#  '145440': ['Generations At Neighbors'],
#  '145626': ['Generations At Oakton'],
#  '145237': ['Generations at Regency'],
#  '145524': ['Generations at Riverview', 'Generations Riverview SNF'],
#  '145039': ['Generations of Peoria'],
#  '145950': ['Generations of Rock Island'],
#  '145979': ['Gibson Area Hospital Annex'],
#  '145367': ['Gillespie Heritage Health'],
#  '145347': ['Gilman Health Care Center'],
#  '145268': ['Glenview Terrace'],
#  '146111': ['Golden Good Shepperd Home'],
#  '145773': ['Good Samaritan Home'],
#  '145930': ['Good Samaritan Rehabilitation/Healthcare'],
#  '146075': ['Granite Nursing and Rehabilitation Center'],
#  '146031': ['Greek American Rehab & Care'],
#  '146166': ['GreenFields of Geneva', 'Greenfields of Geneva'],
#  '145909': ['Greenville Nursing & Rehab'],
#  '145999': ['Grosse Pointe Manor'],
#  '146158': ['Harbor Crest'],
#  '145775': ['Harmony Healthcare and Rehab'],
#  '145774': ['Havana Health Care'],
#  '146015': ['Hearthstone Manor', 'Hearthstone Manor (2)'],
#  '145027': ['Heartland Healthcare Center Moline'],
#  '146030': ['Heartland Senior Living'],
#  '146088': ['Helia Healthcare of Benton'],
#  '145388': ['Helia Healthcare of Olney'],
#  '145452': ['Heritage Health - Dwight'],
#  '145286': ['Heritage Health - Staunton'],
#  '145319': ['Heritage Health El Paso'],
#  '146059': ['Heritage Health Jacksonville'],
#  '145151': ['Heritage Health Mendota'],
#  '145732': ['Heritage Health of Normal'],
#  '145267': ['Heritage Health of Pana'],
#  '145044': ['Heritage Health Peru'],
#  '145229': ['Heritage Health Springfield'],
#  '145062': ['Heritage Health Streator'],
#  '145508': ['Highland Healthcare'],
#  '14A383': ['Highland Oaks'],
#  '146130': ['Hillcrest Retirement Village'],
#  '145500': ['Hillsboro Rehab And Healthcare'],
#  '145609': ['Hillside Rehab and Care', 'Hillside Rehab and Care Center'],
#  '145862': ['Hilltop Skilled Nursing'],
#  '145921': ['Hitz Memorial Home'],
#  '146053': ['Holy Family Villa'],
#  '145269': ['Hope Creek'],
#  '146017': ['Illini Heritage Rehab and Health'],
#  '145703': ['Illini Restorative Care'],
#  '145290': ['Integrity Care of Belleville'],
#  '146188': ['Integrity Care of Smithton'],
#  '145757': ['Integrity Healthcare of Carbondale'],
#  '146092': ['Integrity Healthcare of Herrin'],
#  '145717': ['Integrity Healthcare-Columbia Rehab & Care Center'],
#  '146006': ['Integrity of Anna'],
#  '145922': ['Integrity of Cobden'],
#  '145656': ['Integrity of Godfrey'],
#  '145994': ['Inverness Health and Rehab', 'Inverness Health and Rehab Center'],
#  '145273': ['Jacksonville Skilled Nursing and Rehab Center'],
#  '14A539': ['Jennings Terrace'],
#  '140E248': ['Joliet Terrace'],
#  '145829': ['Kensington Place Nursing And Rehabilitation Center'],
#  '145697': ['Knox County Nursing Home'],
#  '145971': ['Lake Cook Rehab & Healthcare(formerly Rosewood)'],
#  '145986': ['Lake Forest Place - Balmoral'],
#  '145235': ['Lakefront Nursing'],
#  '145256': ['LAKELAND REHABILITATION & HEALTH CARE'],
#  '145694': ['Lakeshore Rehab & Healthcare'],
#  '145646': ['Lakeside Rehab and Healthcare'],
#  '145654': ['Lakeview Nursing and Rehab'],
#  '145761': ['Lakewood Nursing Home'],
#  '145334': ['Landmark of Des Plaines'],
#  '145424': ['Landmark of Richton Park'],
#  '146116': ['LaSalle County Nursing Home'],
#  '145897': ['Lebanon Care Center'],
#  '145382': ['Lee Manor Rehab and Nursing'],
#  '145901': ['Lemont Center'],
#  '146026': ['Lewis Memorial Christian Village'],
#  '145899': ['Lexington Health Care Orland Park'],
#  '145737': ['Lexington Healthcare of La Grange'],
#  '145678': ['Lexington healthcare of Schaumburg'],
#  '145638': ['Lexington of Bloomingdale'],
#  '145700': ['Lexington of Chicago Ridge', 'Lexington Of Chicago Ridge'],
#  '145711': ['Lexington of Elmhurst'],
#  '145816': ['Lexington of Lake Zurich'],
#  '145511': ['Lexington of Lombard'],
#  '145344': ['Libertyville Manor'],
#  '145931': ['Lieberman Geriatric Center'],
#  '145786': ['Lincolnwood Place'],
#  '146185': ['LITTLE SISTERS OF THE POOR ST MARYS HOME',
#   'Little Sisters of the Poor/St. Marys Home'],
#  '146018': ['Little Village Nursing Home'],
#  '146184': ['Luther Oakes'],
#  '145380': ['Lutheran Care Center'],
#  '145768': ['Lutheran Home'],
#  '145848': ['MacNeal Memorial Hospital Rehab/LTC'],
#  '146191': ['MADO Healthcare Uptown'],
#  '145199': ['Manor Care at Arlington Heights',
#   'ManorCare of Arlington Heights'],
#  '145893': ['Manor Care Health Services- Palos Heights West',
#   'ManorCare Health Services-Palos Heights West'],
#  '145684': ['Manor Care Health Services-Homewood'],
#  '145593': ['Manor Care of Libertyville'],
#  '145607': ['Manor Care Palos Heights East', 'ManorCare Palos Heights East'],
#  '146171': ['Manor Court of Carbondale'],
#  '145689': ['ManorCare ElkGrove Village'],
#  '145246': ['Manorcare Hinsdale'],
#  '145087': ['ManorCare Oak Lawn West'],
#  '145990': ['Maple Crest Care Center'],
#  '146046': ['Marshall Rehab'],
#  '145616': ['Mason City Area Nursing Home'],
#  '146074': ['Mason Point'],
#  '145480': ['Mattoon Healthcare'],
#  '145885': ['Mayfield Care Center'],
#  '145494': ['McLean County Nursing Home'],
#  '145710': ['Meadowbrook Manor'],
#  '145874': ['Meadowbrook Manor Naperville'],
#  '145495': ['Medina Nursing Center'],
#  '145102': ['Memorial Convalescent Center'],
#  '146174': ['Mercy Circle'],
#  '146014': ['Mercy Harvard Care Center'],
#  '146142': ['Meridian Village'],
#  '145409': ['Michealsen Health Center'],
#  '145778': ['Midway Neuro and Rehab'],
#  '145713': ['Momence Meadows Nursing & Rehabilitation Center'],
#  '146057': ['Monmouth Nursing Home'],
#  '145471': ['Montebello Healthcare Center'],
#  '145483': ['Montgomery Nursing and Rehab Center'],
#  '145748': ['Montgomery Place'],
#  '145244': ['Mosaic of Lakeshore'],
#  '146162': ['Moweaqua Rehabilitation and Health Care'],
#  '145685': ['Mt. Vernon Countryside Manor'],
#  '14E812': ['Mt. Vernon Healthcare Center'],
#  '146021': ['Nature Trail Health Care Center'],
#  '146115': ['New Athens Home for the Aged'],
#  '145807': ['Newton Care Center'],
#  '145696': ['Niles Nursing and Rehab Center'],
#  '145329': ['Norridge Gardens'],
#  '145974': ['Norwood crossing Skilled Nursing'],
#  '145445': ['Oak Hill'],
#  '145942': ['Oak Lawn Respiratory and Rehab'],
#  '145714': ['Oak Park Oasis'],
#  '145804': ['Oak Trace'],
#  '145458': ['Oakbrook Care'],
#  '146105': ['Oakcrest DeKalb Area Retirement Center'],
#  '145996': ['Oakridge Healthcare Center'],
#  '145376': ['Oakview Nursing and Rehabilitation'],
#  '145772': ['Odd Fellow Rebekah'],
#  '145649': ['Odin Care Center'],
#  '145426': ['Ottawa Pavilion'],
#  '146126': ['Our Lady Of Angels Retirement Home'],
#  '145751': ['PA Peterson at theCitadel'],
#  '145681': ['Palos Heights Nursing and Rehab'],
#  '146071': ['Park Place of Belvidere'],
#  '145765': ['Park View Rehab'],
#  '145989': ['Parker Nursing and Rehabilitation Center'],
#  '145938': ['Parkshore Estates'],
#  '145841': ['Parkway Manor'],
#  '145767': ['Pauls House and Healthcare Center'],
#  '145621': ['Pavilion of Waukegan'],
#  '145350': ['Pearl of Rolling Meadows'],
#  '145597': ['Pekin Manor'],
#  '146078': ['Pershing Garden'],
#  '145838': ['Peterson Park Health Care'],
#  '146175': ['Pinckneyville Nursing and Rehabilitation'],
#  '145261': ['Pine Acres'],
#  '145220': ['Pine Crest Healthcare'],
#  '145489': ['Piper City Rehab'],
#  '145837': ['Pittsfield Manor'],
#  '146128': ['Plymouth Place Senior Living'],
#  '145927': ['Praire Oasis South Holland'],
#  '146003': ['Prairie Creek Village'],
#  '145414': ['Prairie Crossing Living and Rehab'],
#  '145629': ['Prairie Manor Rehab and Nursing'],
#  '145411': ['Prairie Rose'],
#  '145953': ['Prairieview Lutheran Home', 'Prairieview Lutheran Homes'],
#  '146118': ['Prarieview at the Garlands'],
#  '145741': ['Presence MaryHaven', 'Presence Maryhaven'],
#  '146180': ['Presence Nazarethville'],
#  '145536': ['Presence Our Lady of Victory'],
#  '145960': ['Presence Resurrection Life Center'],
#  '145324': ['Presence Resurrection Retirement Community'],
#  '145731': ['Presence St. Benedict'],
#  '145029': ['Presence Villa Franciscan'],
#  '145956': ['Presence Villa Scalabrini Nursing&Rehab Center'],
#  '145657': ['Providence Healthcare & Rehabilitation Center'],
#  '146136': ['Radford Green at Sedgebrook'],
#  '145406': ['Randolph County Care Center'],
#  '145309': ['Red Bud Regional Care Center'],
#  '145615': ['Regency Care of Sterling'],
#  '146177': ['Resthave Care and Rehabilitation'],
#  '145135': ['Richland Nursing and Rehab'],
#  '145771': ['River Bluff Nursing Home'],
#  '145308': ['River View Rehab'],
#  '145651': ['Riverside Rehab and Healthcare'],
#  '146152': ['Rochelle Rehab'],
#  '145975': ['Rochelle Rehab & Healthcare Center'],
#  '145818': ['Rock River Health Care'],
#  '145443': ['Rolling Hills Manor'],
#  '145759': ['Rosiclare Rehabilitation and Health Care Center'],
#  '145618': ['Salem Village NH'],
#  '146134': ['Saline Care Nursing and Rehab'],
#  '146009': ['Selfhelp Home'],
#  '145598': ['Seminary Manor'],
#  '146041': ['Serenity (Aperion) Moline'],
#  '145987': ['Serenity of Galesburg'],
#  '145619': ['Serenity of Lake Storey'],
#  '146098': ['Sharon Healthcare Elms'],
#  '14E888': ['Sharon Healthcare Willows', 'Sharon Healthcare Willows South'],
#  '146036': ['Shawnee Senior Living'],
#  '145441': ['Shelbyville Manor'],
#  '145836': ['Shelbyville Rehabilitation and Health Care Center'],
#  '145482': ['Sheridan Village'],
#  '146110': ['Smith Crossing'],
#  '145904': ['Smith Village'],
#  '145596': ['Snyder Village Assisted Living'],
#  '145825': ['South Elgin Rehab'],
#  '146132': ['South Suburban Rehab Center'],
#  '145914': ['Southpoint Nsg and Rehab'],
#  '146161': ['Southview Manor'],
#  '146172': ['Spring Creek Nursing Home'],
#  '145611': ['St James Manor'],
#  '145457': ['St Vincents Nursing Home'],
#  '145387': ['St. Anthonys Continue Care'],
#  '145720': ['St. Claras Manor'],
#  '145637': ['St. Joseph Village of Chicago'],
#  '145878': ['St. Patricks Residence Nursing & Rehabilitation',
#   'St. Patricks Residence Nursing and Rehabilitation'],
#  '146122': ['St. Pauls'],
#  '145847': ['Stearns Nursing and Rehabilitation Center'],
#  '145895': ['Stephenson Nursing Center'],
#  '145370': ['Sullivan Rehabilitation and Health Care Center'],
#  '146068': ['Sunny Acres Nursing Home'],
#  '145892': ['Sunny Hill Nursing Home'],
#  '145783': ['Sunrise Skilled Nursing Facility'],
#  '145800': ['Sunset Home'],
#  '145981': ['Swansea Rehabilitation and Health Care Center'],
#  '145983': ['Symphony at 87th'],
#  '145946': ['Symphony at Aria'],
#  '145995': ['Symphony at Midway'],
#  '146034': ['Symphony At The Tillers of Oswego',
#   'Symphony at the Tillers of Oswego'],
#  '145819': ['Symphony Buffalo Grove', 'Symphony of Buffalo Grove'],
#  '145337': ['Symphony of Bronzeville'],
#  '145661': ['Symphony of Chicago West'],
#  '145718': ['Symphony of Crestwood'],
#  '145803': ['Symphony of Evanston'],
#  '146143': ['Symphony of Hanover Park'],
#  '145372': ['symphony of joliet', 'Symphony of Joliet'],
#  '145510': ['Symphony of Lincoln Park'],
#  '145764': ['Symphony of Morgan Park'],
#  '145473': ['Symphony of Orchard Valley'],
#  '145977': ['Symphony of South Shore'],
#  '145840': ['Tabor Hills Healthcare'],
#  '145502': ['taylorville care center'],
#  '146048': ['Taylorville Skilled Nursing (fka Meadow Manor)'],
#  '146165': ['The Admiral at the Lake'],
#  '146141': ['The Clare'],
#  '145665': ['The Grove By the Lake'],
#  '145006': ['The Grove Fox Valley', 'The Grove of Fox Valley'],
#  '145070': ['The Grove of Berwyn'],
#  '145339': ['The Grove of Elmhurst'],
#  '145011': ['The Grove of Evanston'],
#  '145307': ['The Grove of La Grange'],
#  '145809': ['The Grove of Northbrook'],
#  '145860': ['The Grove of Skokie'],
#  '145433': ['The Grove St. Charles'],
#  '145031': ['The Lofts Rehabilitation and Nursing of Normal'],
#  '146145': ['The Mather', 'The Mather Evanston'],
#  '146007': ['The Mooring of Arlington heights'],
#  '145221': ['The PARC of Joliet'],
#  '145612': ['The Springs at Crystal Lake'],
#  '146173': ['The Springs of Monarch Landing Skilled Nursing'],
#  '145602': ['The Village at Victory Lakes'],
#  '145460': ['Thrive of Lake County'],
#  '145275': ['Timbercreek Rehab and Healthcare'],
#  '145795': ['Tower Hill Healthcare Center'],
#  '145879': ['Tri-States Nursing & rehab Center'],
#  '146086': ['Tuscola Health Care Center'],
#  '145466': ['Twin Lakes Rehab Center'],
#  '146070': ['Twin Willows Nursing Center'],
#  '145722': ['United Methodist Village'],
#  '145985': ['University Care Center'],
#  '145647': ['University Rehab at Northmoor'],
#  '145364': ['University Rehab Center', 'University Rehabilitation Center'],
#  '145881': ['Uptown Health Center'],
#  '145652': ['Valley Hi'],
#  '145903': ['Vandalia Rehabilitation and Health Care Center'],
#  '146107': ['Vi at the Glen'],
#  '146178': ['Victorian Village'],
#  '145779': ['Villa at Palos Heights'],
#  '145671': ['Villa at South Holland'],
#  '145970': ['Villa at Windsor Park'],
#  '145965': ['Villa Clara Post Acute'],
#  '145721': ['Villa East'],
#  '146019': ['Wabash Christian Retirement'],
#  '146100': ['Walker Nursing Home'],
#  '145336': ['Warren Barr Gold Coast'],
#  '145875': ['Warren Barr Lincoln Park'],
#  '146028': ['Warren Barr Lincolnshire'],
#  '145923': ['Warren Barr North Shore'],
#  '145632': ['Warren Barr South Loop'],
#  '145939': ['Waterfront Terrace'],
#  '145887': ['Wauconda Care'],
#  '146147': ['Waverly Place of Stockton'],
#  '145591': ['Wesley Place'],
#  '146047': ['Wesley Village Healthcare'],
#  '14E392': ['West Chicago Terrace'],
#  '145333': ['West Suburban Nursing & Rehabilitation Center'],
#  '145660': ['Westchester Health and Rehabilitation Center'],
#  '145026': ['Westminster Place'],
#  '145400': ['Westminster Village-Martin Health'],
#  '145338': ['Westmont Manor Health and Rehab Center'],
#  '145664': ['Westside Rehab and CAre'],
#  '146149': ['Westwood Manor'],
#  '145715': ['Wheaton Village'],
#  '145519': ['White Hall Nursing and Rehab'],
#  '145706': ['Whitehall of Deerfield'],
#  '145712': ['Willow Crest Nursing Pavilion'],
#  '145967': ['Windsor Estates'],
#  '146168': ['Winfield Woods Healthcare Center'],
#  '145556': ['Winning Wheels'],
#  '140E170': ['Winston Manor'],
#  '145792': ['Woodbridge Nursing Pavilion'],
#  '145213': ['Wynscape Health and Rehabilitation']}
